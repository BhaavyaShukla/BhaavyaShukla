py
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/ext_modules/mplcursors/_version.py
#    creating: /content/drive/MyDrive/Roydon_task/code_decision_tree/ext_modules/mplcursors/__pycache__/
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/ext_modules/mplcursors/__pycache__/__init__.cpython-310.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/ext_modules/mplcursors/__pycache__/_mplcursors.cpython-310.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/ext_modules/mplcursors/__pycache__/_pick_info.cpython-310.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/ext_modules/mplcursors/__pycache__/_version.cpython-310.pyc
#    creating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/helpers.py
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/__init__.py
#    creating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/__pycache__/
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/__pycache__/helpers.cpython-310.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/__pycache__/helpers.cpython-39.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/__pycache__/__init__.cpython-39.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/datapreprocessing/__pycache__/__init__.cpython-310.pyc
#    creating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/TRAVE1_AF_1cuscino.csv
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/nodes_mode_shape_dofs.txt
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/Readme.md
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/nodes_tower.xlsx
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/Sensors_locations_tower.txt
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/nodes_mode_shape_dofs_tower.xlsx
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/Sensors_loc_tower.xlsx
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/nodes_wood.txt
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/connectivity_wood.txt
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/connectivity.txt
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/nodes.txt
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/5DOF_fixed_ex.txt
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/data_tower.pkl
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/connectivity_tower.xlsx
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/DATA/.~lock.nodes_mode_shape_dofs_tower.xlsx#
#    creating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/
#    creating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/__pycache__/
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/__pycache__/helpers.cpython-310.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/__pycache__/__init__.cpython-310.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/__pycache__/convcheck.cpython-310.pyc
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/__init__.py
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/helpers.py
#   inflating: /content/drive/MyDrive/Roydon_task/code_decision_tree/convergencecheck/convcheck.py

# %%
# %cd /content/drive/MyDrive/Roydon_task/code_decision_tree
# Out:
# /content/drive/MyDrive/Roydon_task/code_decision_tree

# %% [markdown]
# # Run i-AOMA

# %% [markdown]
# ## Import modules and classes

# %%
"""
Intelligent-driven Automatic Operational Modal Analysis i-AOMA
Marco Martino Rosso, Angelo Aloisio, Giuseppe Carlo Marano, and Giuseppe Quaranta

This code is running Monte Carlo (MC) Stochastic Subspace Identification covariance-based (SSI-cov)

Created on March 6 2023
@author: Marco Martino Rosso
"""
# %% Import modules
# !pip install KDEpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
plt.rcParams['font.family'] = 'serif'


from ssicov.ssi import SsiCov
from ssicov.SDres import SdRes
from datapreprocessing.helpers import *
from user_definitions import *
from utilities.utils import *
from qmc.qmc_sampling import QmcSampler
from kde.kdepy import Kde
from rfcore.RFcore import RfCore
from convergencecheck.convcheck import ConvCheck
from plotting_fns.plot_mode_shapes import *
# Out:
# Collecting KDEpy
#   Downloading KDEpy-1.1.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (553 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.4/553.4 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from KDEpy) (1.25.2)
# Requirement already satisfied: scipy<2.0,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from KDEpy) (1.11.4)
# Installing collected packages: KDEpy
# Successfully installed KDEpy-1.1.9

# %%
# Paths definitions
DATA_FILE = 'DATA/5DOF_fixed_ex1.txt'
RESULTS_PATH = 'RESULTS_decisiontree'
N_DIM = 3 # Problem dimensions, accepted integers 2 or 3 for plotting mode shapes in 2D or 3D structures
NODESFILE = 'DATA/nodes1.txt'
CONNECTIVITYFILE = 'DATA/connectivity1.txt'
MONITORED_DOF_FILE = 'DATA/nodes_mode_shape_dofs1.txt'

# Vibration data info
## [Hz]
SAMPLING_FREQUENCY = 40
DECIMATION_FACTOR = 1
FUNDAMENTAL_FREQUENCY = 2
DATAFILTERING = False
BUTTERWORTH_DESIGN = [5,30,'highpass'] # [N,Wn,btype] N:order of the filter; Wn: cut-off frequency; btype: ‘lowpass’, ‘highpass’, ‘bandpass’, ‘bandstop’

# Monte Carlo settings:
MAX_NUM_MC_SIM_PHASE_1 = 100
MAX_NUM_MC_SIM_PHASE_2 = 1000

# Mode shape normalization
# accepted: integer of specific dof otherwise a string 'max'
NORMALIZDOF = 0 #'max'

# KDE prominence peaks
# Prominence may be an arbitrary float between 0 and 1 (suggested 0.1)
# otherwise the string 'automatic'
KDEPROMINENCE = 0.05 # 0.1

# RF intelligent core information content IC threshold
ICTHRESH = 0.1

# i-AOMA PHASE 2
BATCHNSIM = 50         # evaluate the convergence every 50 analyses
CONVMCTHRESH = 0.02    # track relative differences covariance matrix within +-2% for
                       # acceptable shifting convergence band rule (ASCBR)

# Plotting flags
PLOTSIGNALS = True
PLOTSVDOFPSD = True
SAVEPLOTSIGNALS = True
SAVEPLOTSVDOFPSD = True

PLOT_OVERLAPPED_SD = True

# Plotting options
# Standard deviation factor
MODESCALEFCT = 1
MODESTDFCT = 3
MODESTDFCT_ELLIPSES = 3 # it is accounted only for 3D problems
MODE2D_DIRECTION = 'vertical' # it is accounted only for 2D problems, accepted 'vertical' or 'horizontal'

# %% [markdown]
# ## i-AOMA phase 1 exploratory

# %%
# from utilities.utils import *
import numpy

# Import data and decimate
create_results_folder(RESULTS_PATH+'/Phase1')
data = import_data(DATA_FILE)


data, fs = datadecimate(data, fs=SAMPLING_FREQUENCY, q=DECIMATION_FACTOR) #fs: [Hz] Decimated sampling frequency

if DATAFILTERING:
    data = datafiltering(data, fs, BUTTERWORTH_DESIGN)

visualize_plot_signals(data, PLOTSIGNALS, RESULTS_PATH+'/Phase1', fs, SAVEPLOTSIGNALS, labelsformat=['Time [s]','Acceleration [mm/s^2]'])

data1 = []
for i in range(5):
  for j in range(data.shape[0]):
    data1.append(data[j])

data1 = numpy.asarray(data1)

svPSD = visualize_plot_PSD(data1, PLOTSVDOFPSD, RESULTS_PATH+'/Phase1', fs, SAVEPLOTSVDOFPSD)

# i-AOMA Phase 1
print('\n\ni-AOMA phase 1: EXPLORATIVE MC SSI-cov SIMULATIONS\n')
Qmc = QmcSampler(data, FUNDAMENTAL_FREQUENCY, fs)

count_sim = -1
count_sim_effective = -1
discardedpar=[]
discardedpar_errtype=[]
ok_counter = 1

# admissiblepar = []
# stabdiag_columns = ['Frequency', 'Order', 'Label', 'Damp', 'Emme', 'ModeNum', 'SimNumber']
# stabdiag = np.array([])
# stabdiag_modes = np.array([]) # first element is the 'SimNumber' the remaining columns are referred to the dofs

while count_sim_effective < (MAX_NUM_MC_SIM_PHASE_1-1):
    try:
        count_sim += 1
        sampledpar = Qmc.Halton() # it samples an array of [time shift, max order, window lenght, time target]
        # Run SSI-cov for a set of QMC Halton parameters with timeout of 30 seconds
        ssicovSD = SsiCov(dataslice(data, *sampledpar[0][2:]), fs, *sampledpar[0][:2])
        # If achieve here without any error, a new effective simulation is accounted
        count_sim_effective +=1
        # Normalize mode shapes
        ssicovSD.mode_normalization(NORMALIZDOF)
        # Retain only stable poles and associated mode shapes, convert the results in numpy arrays
        ssicovSD.retain_stable_poles(sim_num=count_sim_effective)

        if count_sim_effective == 0:
            # Initialize the Stabilization Diagram results collector object
            SDresults = SdRes(ssicovSD = ssicovSD, admissiblepar = np.array(Qmc.retrieve_last_qmc_sampled()[0]) )
        else: # Update the Stabilization Diagram results collector object with new results
            SDresults.update_results(ssicovSD = ssicovSD, admissiblepar = np.array(Qmc.retrieve_last_qmc_sampled()[0]) )

        print(f'Simulation {count_sim} status: {ok_counter}th OK')
        ok_counter += 1

    except Exception as e:
        if 'could not broadcast input array from shape' in str(e):
            print(f'Simulation {count_sim} status: ErrorType'+ ' ' + 'Incompatible parameters set')
        else:
            print(f'Simulation {count_sim} status: ErrorType'+ ' ' + str(e))
        discardedpar.append(Qmc.retrieve_last_qmc_sampled()[0])
        discardedpar_errtype.append(str(e))
# Out:
# i-AOMA phase 1: EXPLORATIVE MC SSI-cov SIMULATIONS
#
# Simulation 0 status: ErrorType Connection timed out
# Simulation 1 status: ErrorType Connection timed out
# Simulation 2 status: ErrorType Connection timed out
# Simulation 3 status: ErrorType Connection timed out
# Simulation 4 status: ErrorType Connection timed out
# Simulation 5 status: ErrorType Connection timed out
# Simulation 6 status: ErrorType Connection timed out
# Simulation 7 status: ErrorType Connection timed out
# Simulation 8 status: ErrorType Connection timed out
# Simulation 9 status: ErrorType Connection timed out
# Simulation 10 status: ErrorType Connection timed out
# Simulation 11 status: ErrorType Connection timed out
# Simulation 12 status: ErrorType Connection timed out
# Simulation 13 status: ErrorType Connection timed out
# Simulation 14 status: ErrorType Connection timed out
# Simulation 15 status: ErrorType Connection timed out
# Simulation 16 status: ErrorType Connection timed out
# Simulation 17 status: 1th OK
# Simulation 18 status: ErrorType Incompatible parameters set
# Simulation 19 status: ErrorType Connection timed out
# Simulation 20 status: ErrorType Incompatible parameters set
# Simulation 21 status: 2th OK
# Simulation 22 status: ErrorType Connection timed out
# Simulation 23 status: ErrorType Connection timed out
# Simulation 24 status: ErrorType Connection timed out
# Simulation 25 status: ErrorType Connection timed out
# Simulation 26 status: ErrorType Connection timed out
# Simulation 27 status: ErrorType Connection timed out
# Simulation 28 status: ErrorType Connection timed out
# Simulation 29 status: ErrorType Connection timed out
# Simulation 30 status: 3th OK
# Simulation 31 status: 4th OK
# Simulation 32 status: ErrorType Connection timed out
# Simulation 33 status: ErrorType Connection timed out
# Simulation 34 status: 5th OK
# Simulation 35 status: ErrorType Connection timed out
# Simulation 36 status: ErrorType Connection timed out
# Simulation 37 status: ErrorType Connection timed out
# Simulation 38 status: ErrorType Connection timed out
# Simulation 39 status: 6th OK
# Simulation 40 status: ErrorType Connection timed out
# Simulation 41 status: ErrorType Connection timed out
# Simulation 42 status: ErrorType Connection timed out
# Simulation 43 status: ErrorType Connection timed out
# Simulation 545 status: ErrorType Connection timed out
# Simulation 546 status: 91th OK
# Simulation 547 status: ErrorType Connection timed out
# Simulation 548 status: 92th OK
# Simulation 549 status: ErrorType Connection timed out
# Simulation 550 status: ErrorType Connection timed out
# Simulation 551 status: 93th OK
# Simulation 552 status: ErrorType Connection timed out
# Simulation 553 status: ErrorType Connection timed out
# Simulation 554 status: ErrorType Connection timed out
# Simulation 555 status: ErrorType Connection timed out
# Simulation 556 status: ErrorType Connection timed out
# Simulation 557 status: ErrorType Connection timed out
# Simulation 558 status: ErrorType Incompatible parameters set
# Simulation 559 status: 94th OK
# Simulation 560 status: 95th OK
# Simulation 561 status: ErrorType Connection timed out
# Simulation 562 status: ErrorType Connection timed out
# Simulation 563 status: 96th OK
# Simulation 564 status: ErrorType Connection timed out
# Simulation 565 status: 97th OK
# Simulation 566 status: ErrorType Connection timed out
# Simulation 567 status: 98th OK
# Simulation 568 status: ErrorType Connection timed out
# Simulation 569 status: ErrorType Connection timed out
# Simulation 570 status: ErrorType Connection timed out
# Simulation 571 status: ErrorType Connection timed out
# Simulation 572 status: ErrorType Connection timed out
# Simulation 573 status: ErrorType Connection timed out
# Simulation 574 status: ErrorType Incompatible parameters set
# Simulation 575 status: ErrorType Incompatible parameters set
# Simulation 576 status: ErrorType Connection timed out
# Simulation 577 status: ErrorType Incompatible parameters set
# Simulation 578 status: 99th OK
# Simulation 579 status: ErrorType Connection timed out
# Simulation 580 status: ErrorType Connection timed out
# Simulation 581 status: ErrorType Incompatible parameters set
# Simulation 582 status: ErrorType Connection timed out
# Simulation 583 status: ErrorType Incompatible parameters set
# Simulation 584 status: 100th OK

# %%
print(f'\nSimulations evaluated {count_sim+1}, discarding {len(discardedpar)} parameters to collect {MAX_NUM_MC_SIM_PHASE_1} useful results')

SDresults.plot_overlapped_SD(fs,PLOT_OVERLAPPED_SD, RESULTS_PATH+'/Phase1')
SDresults.plot_overlapped_SD_stable(fs,PLOT_OVERLAPPED_SD, RESULTS_PATH+'/Phase1')
SDresults.export_results_to_file(RESULTS_PATH+'/Phase1')
#  create attribute which join in a single array poles and modes SDresults.jointpolesmodes
SDresults.jointpolesarray_and_modesarray() # SDresults.joint_col_names [ ['Frequency', 'Order', 'Label', 'Damp', 'Emme', 'ModeNum', 'SimNumber'], ['SimNumber','dof','dof','...'] ]

# KDE
kdeSD = Kde(SDresults.jointpolesmodes, fs, KDEPROMINENCE)
kdeSD.plot_kde_freq(RESULTS_PATH+'/Phase1')
kdeSD.select_modes_clusters()
# kdeSD.plot_select_modes_clusters(RESULTS_PATH+'/Phase1')
print(f'Found {kdeSD.peaksFFTKDE.shape[0]:d} peaks at {kdeSD.x[kdeSD.peaksFFTKDE]} Hz with prominence of {kdeSD.KDEPROMINENCE:.4f}.\n')
print(f'Found {len(kdeSD.Frequency_dataset):d} poles clusters within {kdeSD.KDEbwFactor:d} times the bandwidth of {kdeSD.bw:.4f} Hz.\n')
# IC
IC = kdeSD.information_content(SDresults.selectedpoles_totnum)
kdeSD.save_plot_IC(MAX_NUM_MC_SIM_PHASE_1-1, ICTHRESH, RESULTS_PATH+'/Phase1')
kdeSD.export_results_to_file(RESULTS_PATH+'/Phase1')
# RF
RF = RfCore(ICTHRESH, IC, SDresults.admissiblepar, discardedpar)
RF.fit()
RF.save_model_to_file(RESULTS_PATH+'/Phase1')
RF.evaluate(RF.x, RF.y)
# Out:
# Simulations evaluated 585, discarding 485 parameters to collect 100 useful results
# All cluster are full with 1 times of the bandwidth of 0.0038
# Found 19 peaks at [ 4.23227164  4.52652313  4.88157936  4.95324209  5.74044627  5.9988664
#   6.37238121  8.40391089  8.4864316   8.65798782  8.86103221  9.65257958
#  10.79918319 11.61461814 12.79162411 14.03812121 14.39752063 15.20969818
#  19.25212736] Hz with prominence of 0.0500.
#
# Found 19 poles clusters within 1 times the bandwidth of 0.0038 Hz.
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99       568
#          1.0       0.74      0.82      0.78        17
#
#     accuracy                           0.99       585
#    macro avg       0.87      0.91      0.89       585
# weighted avg       0.99      0.99      0.99       585
#
# Confusion Matrix:
# [[563   5]
#  [  3  14]]

# %%
# !zip -r /content/RESULTS_phase1.zip /content/drive/MyDrive/Roydon_task/code_decision_tree/RESULTS
# from google.colab import files
# files.download("/content/RESULTS_phase1.zip")

# %% [markdown]
# ## i-AOMA phase 2 intelligent MC SSI-cov

# %%
# i-AOMA Phase 2 che parte dai risultati già immagazzinati della fase 1
print('\n\ni-AOMA phase 2: INTELLIGENT Decision Tree DRIVEN MC SSI-cov SIMULATIONS\n')
starting_sim_num = [count_sim, len(discardedpar), count_sim_effective]
continueMCsim=1
# Initialize convergence check object which stores uncertainty propagation results
modesconv = ConvCheck(kdeSD.Frequency_dataset, MAX_NUM_MC_SIM_PHASE_1)
last_check_sim = count_sim_effective

create_results_folder(RESULTS_PATH+'/Phase2')
create_results_folder(RESULTS_PATH+'/Phase2/Backup_convergence_checks') #???? not implemented for now because saving results will slow down the code

while continueMCsim and (count_sim_effective < (MAX_NUM_MC_SIM_PHASE_1 + MAX_NUM_MC_SIM_PHASE_2 -1)) :
    try:
        count_sim += 1
        sampledpar = Qmc.Halton() # it samples an array of [time shift, max order, window lenght, time target]
        y_pred = RF.predict( np.array(Qmc.retrieve_last_qmc_sampled()[0]) )
        print(y_pred)
        if y_pred == 1:
            print(f'Simulation {count_sim} status: Accepted by Decision tree')
            # Run SSI-cov for a set of QMC Halton parameters with timeout of 30 seconds
            ssicovSD = SsiCov(dataslice(data, *sampledpar[0][2:]), fs, *sampledpar[0][:2])
            # If achieve here without any error, a new effective simulation is accounted
            count_sim_effective +=1
            # Normalize mode shapes
            ssicovSD.mode_normalization(NORMALIZDOF)
            # Retain only stable poles and associated mode shapes, convert the results in numpy arrays
            ssicovSD.retain_stable_poles(sim_num=count_sim_effective)

            SDresults.update_results(ssicovSD = ssicovSD, admissiblepar = np.array(Qmc.retrieve_last_qmc_sampled()[0]) )

            print(f'Simulation {count_sim} status: OK')
        else:
            print(f'Simulation {count_sim} status: Discarded by Decision tree')
            discardedpar.append(Qmc.retrieve_last_qmc_sampled()[0])
            discardedpar_errtype.append(f'Decision tree prediction: 0')

    except Exception as e:
        if 'could not broadcast input array from shape' in str(e):
            print(f'Simulation {count_sim} status: ErrorType'+ ' ' + 'Incompatible parameters set')
        else:
            print(f'Simulation {count_sim} status: ErrorType'+ ' ' + str(e))
        discardedpar.append(Qmc.retrieve_last_qmc_sampled()[0])
        discardedpar_errtype.append(str(e))

    if ((count_sim_effective - starting_sim_num[2]) % BATCHNSIM == 0) and (count_sim_effective - starting_sim_num[2])!=0 \
        and (last_check_sim != count_sim_effective) :
        print('********** Check convergence criteria ********** \n')
        print(f'Actual simulations so far: {count_sim_effective+1}')

        create_results_folder(RESULTS_PATH+f'/Phase2/Backup_convergence_checks/{count_sim_effective+1}')


        #  create attribute which join in a single array poles and modes SDresults.jointpolesmodes
        SDresults.jointpolesarray_and_modesarray() # SDresults.joint_col_names [ ['Frequency', 'Order', 'Label', 'Damp', 'Emme', 'ModeNum', 'SimNumber'], ['SimNumber','dof','dof','...'] ]
        kdeSD.select_peaks_phase_two(SDresults.jointpolesmodes)
        kdeSD.plot_kde_freq(RESULTS_PATH+f'/Phase2/Backup_convergence_checks/{count_sim_effective+1}') # comment it after checking everything is correct
        kdeSD.select_modes_clusters()
        # kdeSD.plot_select_modes_clusters(RESULTS_PATH+f'/Phase2/Backup_convergence_checks/{count_sim_effective+1}') # comment it after checking everything is correct

        convergence_reached = modesconv.update_converg_sim(kdeSD.Frequency_dataset, count_sim_effective, last_check_sim, CONVMCTHRESH)

        modesconv.plot_convergence_curves(CONVMCTHRESH, RESULTS_PATH+f'/Phase2/Backup_convergence_checks/{count_sim_effective+1}') # comment it after checking everything is correct

        last_check_sim = count_sim_effective

        if convergence_reached:
            print('********** Stopping criteria reached! ********** \n\n')
            continueMCsim=0
        else:
            print('********** Convergence criteria not reached yet ********** \n\n')

    if count_sim_effective == (MAX_NUM_MC_SIM_PHASE_1 + MAX_NUM_MC_SIM_PHASE_2 -1):
        print('********** Convergence criteria not reached yet, but maximum allowed number of actual simulations reached ********** \n')

print(f'Simulations evaluated in total {count_sim+1}:\n' + \
      f'Phase 1: Simulations {starting_sim_num[0]+1}, discarding {starting_sim_num[1]}, collecting {MAX_NUM_MC_SIM_PHASE_1} useful results \n' + \
      f'Phase 2: Simulations {(count_sim-starting_sim_num[0])}, intelligently discarding {(len(discardedpar)-starting_sim_num[1])}, collecting {count_sim_effective-starting_sim_num[2]} useful results \n\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# 0
# Simulation 23320 status: Discarded by Decision tree
# 0
# Simulation 23321 status: Discarded by Decision tree
# 0
# Simulation 23322 status: Discarded by Decision tree
# 0
# Simulation 23323 status: Discarded by Decision tree
# 0
# Simulation 23324 status: Discarded by Decision tree
# 0
# Simulation 23325 status: Discarded by Decision tree
# 0
# Simulation 23326 status: Discarded by Decision tree
# 0
# Simulation 23327 status: Discarded by Decision tree
# 0
# Simulation 23328 status: Discarded by Decision tree
# 0
# Simulation 23329 status: Discarded by Decision tree
# 0
# Simulation 23330 status: Discarded by Decision tree
# 1
# Simulation 23331 status: Accepted by Decision tree
# Simulation 23331 status: OK
# 1
# Simulation 23332 status: Accepted by Decision tree
# Simulation 23332 status: ErrorType Incompatible parameters set
# 0
# Simulation 23333 status: Discarded by Decision tree
# 0
# Simulation 23334 status: Discarded by Decision tree
# 0
# Simulation 23335 status: Discarded by Decision tree
# 0
# Simulation 23336 status: Discarded by Decision tree
# 0
# Simulation 23337 status: Discarded by Decision tree
# 0
# Simulation 23338 status: Discarded by Decision tree
# 0
# Simulation 23339 status: Discarded by Decision tree
# 0
# Simulation 23340 status: Discarded by Decision tree
# 0
# Simulation 23341 status: Discarded by Decision tree
# 0
# Simulation 23342 status: Discarded by Decision tree
# 0
# Simulation 23343 status: Discarded by Decision tree
# 0
# Simulation 23344 status: Discarded by Decision tree
# 0
# Simulation 23345 status: Discarded by Decision tree
# 0
# Simulation 23346 status: Discarded by Decision tree
# 0
# Simulation 23347 status: Discarded by Decision tree
# 0
# Simulation 23348 status: Discarded by Decision tree
# 0
# Simulation 23349 status: Discarded by Decision tree
# 0
# Simulation 23350 status: Discarded by Decision tree
# 0
# Simulation 23351 status: Discarded by Decision tree
# 0
# Simulation 23352 status: Discarded by Decision tree
# 0
# Simulation 23353 status: Discarded by Decision tree
# 0
# Simulation 23354 status: Discarded by Decision tree
# 0
# Simulation 23355 status: Discarded by Decision tree
# 0
# Simulation 23356 status: Discarded by Decision tree
# 0
# Simulation 23357 status: Discarded by Decision tree
# 0
# Simulation 23358 status: Discarded by Decision tree
# 0
# Simulation 23359 status: Discarded by Decision tree
# 0
# Simulation 23360 status: Discarded by Decision tree
# 0
# Simulation 23361 status: Discarded by Decision tree
# 0
# Simulation 23362 status: Discarded by Decision tree
# 0
# Simulation 23363 status: Discarded by Decision tree
# 0
# Simulation 23364 status: Discarded by Decision tree
# 1
# Simulation 23365 status: Accepted by Decision tree
# Simulation 23365 status: ErrorType Incompatible parameters set
# 0
# Simulation 23366 status: Discarded by Decision tree
# 0
# Simulation 23367 status: Discarded by Decision tree
# 1
# Simulation 23368 status: Accepted by Decision tree
# Simulation 23368 status: OK
# 0
# Simulation 23369 status: Discarded by Decision tree
# 0
# Simulation 23370 status: Discarded by Decision tree
# 0
# Simulation 23371 status: Discarded by Decision tree
# 0
# Simulation 23372 status: Discarded by Decision tree
# 0
# Simulation 23373 status: Discarded by Decision tree
# 0
# Simulation 23374 status: Discarded by Decision tree
# 0
# Simulation 23375 status: Discarded by Decision tree
# 0
# Simulation 23376 status: Discarded by Decision tree
# 0
# Simulation 23377 status: Discarded by Decision tree
# 0
# Simulation 23378 status: Discarded by Decision tree
# 1
# Simulation 23379 status: Accepted by Decision tree
# Simulation 23379 status: OK
# 0
# Simulation 23380 status: Discarded by Decision tree
# 0
# Simulation 23381 status: Discarded by Decision tree
# 0
# Simulation 23382 status: Discarded by Decision tree
# 0
# Simulation 23383 status: Discarded by Decision tree
# 0
# Simulation 23384 status: Discarded by Decision tree
# 0
# Simulation 23385 status: Discarded by Decision tree
# 0
# Simulation 23386 status: Discarded by Decision tree
# 0
# Simulation 23387 status: Discarded by Decision tree
# 0
# Simulation 23388 status: Discarded by Decision tree
# 0
# Simulation 23389 status: Discarded by Decision tree
# 0
# Simulation 23390 status: Discarded by Decision tree
# 0
# Simulation 23391 status: Discarded by Decision tree
# 0
# Simulation 23392 status: Discarded by Decision tree
# 0
# Simulation 23393 status: Discarded by Decision tree
# 0
# Simulation 23394 status: Discarded by Decision tree
# 0
# Simulation 23395 status: Discarded by Decision tree
# 0
# Simulation 23396 status: Discarded by Decision tree
# 0
# Simulation 23397 status: Discarded by Decision tree
# 0
# Simulation 23398 status: Discarded by Decision tree
# 0
# Simulation 23399 status: Discarded by Decision tree
# 0
# Simulation 23400 status: Discarded by Decision tree
# 0
# Simulation 23401 status: Discarded by Decision tree
# 0
# Simulation 23402 status: Discarded by Decision tree
# 0
# Simulation 23403 status: Discarded by Decision tree
# 0
# Simulation 23404 status: Discarded by Decision tree
# 0
# Simulation 23405 status: Discarded by Decision tree
# 0
# Simulation 23406 status: Discarded by Decision tree
# 0
# Simulation 23407 status: Discarded by Decision tree
# 0
# Simulation 23408 status: Discarded by Decision tree
# 0
# Simulation 23409 status: Discarded by Decision tree
# 0
# Simulation 23410 status: Discarded by Decision tree
# 0
# Simulation 23411 status: Discarded by Decision tree
# 0
# Simulation 23412 status: Discarded by Decision tree
# 0
# Simulation 23413 status: Discarded by Decision tree
# 0
# Simulation 23414 status: Discarded by Decision tree
# 0
# Simulation 23415 status: Discarded by Decision tree
# 0
# Simulation 23416 status: Discarded by Decision tree
# 0
# Simulation 23417 status: Discarded by Decision tree
# 0
# Simulation 23418 status: Discarded by Decision tree
# 0
# Simulation 23419 status: Discarded by Decision tree
# 0
# Simulation 23420 status: Discarded by Decision tree
# 0
# Simulation 23421 status: Discarded by Decision tree
# 0
# Simulation 23422 status: Discarded by Decision tree
# 0
# Simulation 23423 status: Discarded by Decision tree
# 0
# Simulation 23424 status: Discarded by Decision tree
# 0
# Simulation 23425 status: Discarded by Decision tree
# 0
# Simulation 23426 status: Discarded by Decision tree
# 0
# Simulation 23427 status: Discarded by Decision tree
# 0
# Simulation 23428 status: Discarded by Decision tree
# 0
# Simulation 23429 status: Discarded by Decision tree
# 0
# Simulation 23430 status: Discarded by Decision tree
# 0
# Simulation 23431 status: Discarded by Decision tree
# 1
# Simulation 23432 status: Accepted by Decision tree
# Simulation 23432 status: OK
# 0
# Simulation 23433 status: Discarded by Decision tree
# 0
# Simulation 23434 status: Discarded by Decision tree
# 0
# Simulation 23435 status: Discarded by Decision tree
# 0
# Simulation 23436 status: Discarded by Decision tree
# 0
# Simulation 23437 status: Discarded by Decision tree
# 1
# Simulation 23438 status: Accepted by Decision tree
# Simulation 23438 status: OK
# 0
# Simulation 23439 status: Discarded by Decision tree
# 0
# Simulation 23440 status: Discarded by Decision tree
# 0
# Simulation 23441 status: Discarded by Decision tree
# 0
# Simulation 23442 status: Discarded by Decision tree
# 0
# Simulation 23443 status: Discarded by Decision tree
# 0
# Simulation 23444 status: Discarded by Decision tree
# 0
# Simulation 23445 status: Discarded by Decision tree
# 0
# Simulation 23446 status: Discarded by Decision tree
# 0
# Simulation 23447 status: Discarded by Decision tree
# 0
# Simulation 23448 status: Discarded by Decision tree
# 0
# Simulation 23449 status: Discarded by Decision tree
# 0
# Simulation 23450 status: Discarded by Decision tree
# 0
# Simulation 23451 status: Discarded by Decision tree
# 0
# Simulation 23452 status: Discarded by Decision tree
# 0
# Simulation 23453 status: Discarded by Decision tree
# 0
# Simulation 23454 status: Discarded by Decision tree
# 0
# Simulation 23455 status: Discarded by Decision tree
# 0
# Simulation 23456 status: Discarded by Decision tree
# 0
# Simulation 23457 status: Discarded by Decision tree
# 0
# Simulation 23458 status: Discarded by Decision tree
# 0
# Simulation 23459 status: Discarded by Decision tree
# 0
# Simulation 23460 status: Discarded by Decision tree
# 1
# Simulation 23461 status: Accepted by Decision tree
# Simulation 23461 status: OK
# 0
# Simulation 23462 status: Discarded by Decision tree
# 0
# Simulation 23463 status: Discarded by Decision tree
# 0
# Simulation 23464 status: Discarded by Decision tree
# 0
# Simulation 23465 status: Discarded by Decision tree
# 0
# Simulation 23466 status: Discarded by Decision tree
# 0
# Simulation 23467 status: Discarded by Decision tree
# 0
# Simulation 23468 status: Discarded by Decision tree
# 0
# Simulation 23469 status: Discarded by Decision tree
# 0
# Simulation 23470 status: Discarded by Decision tree
# 0
# Simulation 23471 status: Discarded by Decision tree
# 0
# Simulation 23472 status: Discarded by Decision tree
# 0
# Simulation 23473 status: Discarded by Decision tree
# 0
# Simulation 23474 status: Discarded by Decision tree
# 1
# Simulation 23475 status: Accepted by Decision tree
# Simulation 23475 status: OK
# 0
# Simulation 23476 status: Discarded by Decision tree
# 0
# Simulation 23477 status: Discarded by Decision tree
# 0
# Simulation 23478 status: Discarded by Decision tree
# 0
# Simulation 23479 status: Discarded by Decision tree
# 0
# Simulation 23480 status: Discarded by Decision tree
# 0
# Simulation 23481 status: Discarded by Decision tree
# 0
# Simulation 23482 status: Discarded by Decision tree
# 0
# Simulation 23483 status: Discarded by Decision tree
# 0
# Simulation 23484 status: Discarded by Decision tree
# 0
# Simulation 23485 status: Discarded by Decision tree
# 0
# Simulation 23486 status: Discarded by Decision tree
# 0
# Simulation 23487 status: Discarded by Decision tree
# 0
# Simulation 23488 status: Discarded by Decision tree
# 0
# Simulation 23489 status: Discarded by Decision tree
# 0
# Simulation 23490 status: Discarded by Decision tree
# 0
# Simulation 23491 status: Discarded by Decision tree
# 0
# Simulation 23492 status: Discarded by Decision tree
# 0
# Simulation 23493 status: Discarded by Decision tree
# 0
# Simulation 23494 status: Discarded by Decision tree
# 0
# Simulation 23495 status: Discarded by Decision tree
# 0
# Simulation 23496 status: Discarded by Decision tree
# 0
# Simulation 23497 status: Discarded by Decision tree
# 0
# Simulation 23498 status: Discarded by Decision tree
# 0
# Simulation 23499 status: Discarded by Decision tree
# 0
# Simulation 23500 status: Discarded by Decision tree
# 0
# Simulation 23501 status: Discarded by Decision tree
# 1
# Simulation 23502 status: Accepted by Decision tree
# Simulation 23502 status: OK
# 0
# Simulation 23503 status: Discarded by Decision tree
# 0
# Simulation 23504 status: Discarded by Decision tree
# 0
# Simulation 23505 status: Discarded by Decision tree
# 0
# Simulation 23506 status: Discarded by Decision tree
# 0
# Simulation 23507 status: Discarded by Decision tree
# 0
# Simulation 23508 status: Discarded by Decision tree
# 0
# Simulation 23509 status: Discarded by Decision tree
# 0
# Simulation 23510 status: Discarded by Decision tree
# 0
# Simulation 23511 status: Discarded by Decision tree
# 0
# Simulation 23512 status: Discarded by Decision tree
# 0
# Simulation 23513 status: Discarded by Decision tree
# 0
# Simulation 23514 status: Discarded by Decision tree
# 0
# Simulation 23515 status: Discarded by Decision tree
# 0
# Simulation 23516 status: Discarded by Decision tree
# 0
# Simulation 23517 status: Discarded by Decision tree
# 0
# Simulation 23518 status: Discarded by Decision tree
# 0
# Simulation 23519 status: Discarded by Decision tree
# 0
# Simulation 23520 status: Discarded by Decision tree
# 0
# Simulation 23521 status: Discarded by Decision tree
# 0
# Simulation 23522 status: Discarded by Decision tree
# 0
# Simulation 23523 status: Discarded by Decision tree
# 0
# Simulation 23524 status: Discarded by Decision tree
# 0
# Simulation 23525 status: Discarded by Decision tree
# 0
# Simulation 23526 status: Discarded by Decision tree
# 0
# Simulation 23527 status: Discarded by Decision tree
# 0
# Simulation 23528 status: Discarded by Decision tree
# 0
# Simulation 23529 status: Discarded by Decision tree
# 0
# Simulation 23530 status: Discarded by Decision tree
# 0
# Simulation 23531 status: Discarded by Decision tree
# 0
# Simulation 23532 status: Discarded by Decision tree
# 0
# Simulation 23533 status: Discarded by Decision tree
# 0
# Simulation 23534 status: Discarded by Decision tree
# 0
# Simulation 23535 status: Discarded by Decision tree
# 0
# Simulation 23536 status: Discarded by Decision tree
# 1
# Simulation 23537 status: Accepted by Decision tree
# Simulation 23537 status: OK
# 0
# Simulation 23538 status: Discarded by Decision tree
# 0
# Simulation 23539 status: Discarded by Decision tree
# 0
# Simulation 23540 status: Discarded by Decision tree
# 0
# Simulation 23541 status: Discarded by Decision tree
# 0
# Simulation 23542 status: Discarded by Decision tree
# 0
# Simulation 23543 status: Discarded by Decision tree
# 0
# Simulation 23544 status: Discarded by Decision tree
# 0
# Simulation 23545 status: Discarded by Decision tree
# 0
# Simulation 23546 status: Discarded by Decision tree
# 0
# Simulation 23547 status: Discarded by Decision tree
# 0
# Simulation 23548 status: Discarded by Decision tree
# 0
# Simulation 23549 status: Discarded by Decision tree
# 0
# Simulation 23550 status: Discarded by Decision tree
# 0
# Simulation 23551 status: Discarded by Decision tree
# 0
# Simulation 23552 status: Discarded by Decision tree
# 0
# Simulation 23553 status: Discarded by Decision tree
# 0
# Simulation 23554 status: Discarded by Decision tree
# 0
# Simulation 23555 status: Discarded by Decision tree
# 0
# Simulation 23556 status: Discarded by Decision tree
# 0
# Simulation 23557 status: Discarded by Decision tree
# 0
# Simulation 23558 status: Discarded by Decision tree
# 0
# Simulation 23559 status: Discarded by Decision tree
# 0
# Simulation 23560 status: Discarded by Decision tree
# 0
# Simulation 23561 status: Discarded by Decision tree
# 0
# Simulation 23562 status: Discarded by Decision tree
# 0
# Simulation 23563 status: Discarded by Decision tree
# 0
# Simulation 23564 status: Discarded by Decision tree
# 0
# Simulation 23565 status: Discarded by Decision tree
# 0
# Simulation 23566 status: Discarded by Decision tree
# 0
# Simulation 23567 status: Discarded by Decision tree
# 0
# Simulation 23568 status: Discarded by Decision tree
# 0
# Simulation 23569 status: Discarded by Decision tree
# 0
# Simulation 23570 status: Discarded by Decision tree
# 0
# Simulation 23571 status: Discarded by Decision tree
# 0
# Simulation 23572 status: Discarded by Decision tree
# 0
# Simulation 23573 status: Discarded by Decision tree
# 0
# Simulation 23574 status: Discarded by Decision tree
# 0
# Simulation 23575 status: Discarded by Decision tree
# 0
# Simulation 23576 status: Discarded by Decision tree
# 0
# Simulation 23577 status: Discarded by Decision tree
# 0
# Simulation 23578 status: Discarded by Decision tree
# 0
# Simulation 23579 status: Discarded by Decision tree
# 0
# Simulation 23580 status: Discarded by Decision tree
# 0
# Simulation 23581 status: Discarded by Decision tree
# 0
# Simulation 23582 status: Discarded by Decision tree
# 0
# Simulation 23583 status: Discarded by Decision tree
# 0
# Simulation 23584 status: Discarded by Decision tree
# 0
# Simulation 23585 status: Discarded by Decision tree
# 0
# Simulation 23586 status: Discarded by Decision tree
# 0
# Simulation 23587 status: Discarded by Decision tree
# 1
# Simulation 23588 status: Accepted by Decision tree
# Simulation 23588 status: OK
# 0
# Simulation 23589 status: Discarded by Decision tree
# 0
# Simulation 23590 status: Discarded by Decision tree
# 0
# Simulation 23591 status: Discarded by Decision tree
# 0
# Simulation 23592 status: Discarded by Decision tree
# 0
# Simulation 23593 status: Discarded by Decision tree
# 0
# Simulation 23594 status: Discarded by Decision tree
# 0
# Simulation 23595 status: Discarded by Decision tree
# 0
# Simulation 23596 status: Discarded by Decision tree
# 0
# Simulation 23597 status: Discarded by Decision tree
# 0
# Simulation 23598 status: Discarded by Decision tree
# 0
# Simulation 23599 status: Discarded by Decision tree
# 0
# Simulation 23600 status: Discarded by Decision tree
# 0
# Simulation 23601 status: Discarded by Decision tree
# 0
# Simulation 23602 status: Discarded by Decision tree
# 0
# Simulation 23603 status: Discarded by Decision tree
# 0
# Simulation 23604 status: Discarded by Decision tree
# 0
# Simulation 23605 status: Discarded by Decision tree
# 0
# Simulation 23606 status: Discarded by Decision tree
# 0
# Simulation 23607 status: Discarded by Decision tree
# 0
# Simulation 23608 status: Discarded by Decision tree
# 0
# Simulation 23609 status: Discarded by Decision tree
# 0
# Simulation 23610 status: Discarded by Decision tree
# 0
# Simulation 23611 status: Discarded by Decision tree
# 0
# Simulation 23612 status: Discarded by Decision tree
# 0
# Simulation 23613 status: Discarded by Decision tree
# 0
# Simulation 23614 status: Discarded by Decision tree
# 0
# Simulation 23615 status: Discarded by Decision tree
# 0
# Simulation 23616 status: Discarded by Decision tree
# 0
# Simulation 23617 status: Discarded by Decision tree
# 0
# Simulation 23618 status: Discarded by Decision tree
# 0
# Simulation 23619 status: Discarded by Decision tree
# 0
# Simulation 23620 status: Discarded by Decision tree
# 0
# Simulation 23621 status: Discarded by Decision tree
# 0
# Simulation 23622 status: Discarded by Decision tree
# 0
# Simulation 23623 status: Discarded by Decision tree
# 1
# Simulation 23624 status: Accepted by Decision tree
# Simulation 23624 status: OK
# 0
# Simulation 23625 status: Discarded by Decision tree
# 0
# Simulation 23626 status: Discarded by Decision tree
# 0
# Simulation 23627 status: Discarded by Decision tree
# 0
# Simulation 23628 status: Discarded by Decision tree
# 0
# Simulation 23629 status: Discarded by Decision tree
# 0
# Simulation 23630 status: Discarded by Decision tree
# 0
# Simulation 23631 status: Discarded by Decision tree
# 0
# Simulation 23632 status: Discarded by Decision tree
# 0
# Simulation 23633 status: Discarded by Decision tree
# 0
# Simulation 23634 status: Discarded by Decision tree
# 0
# Simulation 23635 status: Discarded by Decision tree
# 0
# Simulation 23636 status: Discarded by Decision tree
# 0
# Simulation 23637 status: Discarded by Decision tree
# 0
# Simulation 23638 status: Discarded by Decision tree
# 0
# Simulation 23639 status: Discarded by Decision tree
# 0
# Simulation 23640 status: Discarded by Decision tree
# 0
# Simulation 23641 status: Discarded by Decision tree
# 0
# Simulation 23642 status: Discarded by Decision tree
# 0
# Simulation 23643 status: Discarded by Decision tree
# 0
# Simulation 23644 status: Discarded by Decision tree
# 0
# Simulation 23645 status: Discarded by Decision tree
# 0
# Simulation 23646 status: Discarded by Decision tree
# 0
# Simulation 23647 status: Discarded by Decision tree
# 0
# Simulation 23648 status: Discarded by Decision tree
# 0
# Simulation 23649 status: Discarded by Decision tree
# 0
# Simulation 23650 status: Discarded by Decision tree
# 1
# Simulation 23651 status: Accepted by Decision tree
# Simulation 23651 status: OK
# 0
# Simulation 23652 status: Discarded by Decision tree
# 0
# Simulation 23653 status: Discarded by Decision tree
# 0
# Simulation 23654 status: Discarded by Decision tree
# 0
# Simulation 23655 status: Discarded by Decision tree
# 1
# Simulation 23656 status: Accepted by Decision tree
# Simulation 23656 status: OK
# 0
# Simulation 23657 status: Discarded by Decision tree
# 0
# Simulation 23658 status: Discarded by Decision tree
# 0
# Simulation 23659 status: Discarded by Decision tree
# 0
# Simulation 23660 status: Discarded by Decision tree
# 0
# Simulation 23661 status: Discarded by Decision tree
# 0
# Simulation 23662 status: Discarded by Decision tree
# 0
# Simulation 23663 status: Discarded by Decision tree
# 0
# Simulation 23664 status: Discarded by Decision tree
# 0
# Simulation 23665 status: Discarded by Decision tree
# 0
# Simulation 23666 status: Discarded by Decision tree
# 0
# Simulation 23667 status: Discarded by Decision tree
# 0
# Simulation 23668 status: Discarded by Decision tree
# 0
# Simulation 23669 status: Discarded by Decision tree
# 0
# Simulation 23670 status: Discarded by Decision tree
# 0
# Simulation 23671 status: Discarded by Decision tree
# 0
# Simulation 23672 status: Discarded by Decision tree
# 0
# Simulation 23673 status: Discarded by Decision tree
# 0
# Simulation 23674 status: Discarded by Decision tree
# 0
# Simulation 23675 status: Discarded by Decision tree
# 0
# Simulation 23676 status: Discarded by Decision tree
# 0
# Simulation 23677 status: Discarded by Decision tree
# 0
# Simulation 23678 status: Discarded by Decision tree
# 0
# Simulation 23679 status: Discarded by Decision tree
# 0
# Simulation 23680 status: Discarded by Decision tree
# 0
# Simulation 23681 status: Discarded by Decision tree
# 0
# Simulation 23682 status: Discarded by Decision tree
# 1
# Simulation 23683 status: Accepted by Decision tree
# Simulation 23683 status: OK
# 0
# Simulation 23684 status: Discarded by Decision tree
# 0
# Simulation 23685 status: Discarded by Decision tree
# 0
# Simulation 23686 status: Discarded by Decision tree
# 0
# Simulation 23687 status: Discarded by Decision tree
# 0
# Simulation 23688 status: Discarded by Decision tree
# 0
# Simulation 23689 status: Discarded by Decision tree
# 0
# Simulation 23690 status: Discarded by Decision tree
# 0
# Simulation 23691 status: Discarded by Decision tree
# 0
# Simulation 23692 status: Discarded by Decision tree
# 0
# Simulation 23693 status: Discarded by Decision tree
# 0
# Simulation 23694 status: Discarded by Decision tree
# 0
# Simulation 23695 status: Discarded by Decision tree
# 0
# Simulation 23696 status: Discarded by Decision tree
# 0
# Simulation 23697 status: Discarded by Decision tree
# 0
# Simulation 23698 status: Discarded by Decision tree
# 0
# Simulation 23699 status: Discarded by Decision tree
# 0
# Simulation 23700 status: Discarded by Decision tree
# 0
# Simulation 23701 status: Discarded by Decision tree
# 0
# Simulation 23702 status: Discarded by Decision tree
# 1
# Simulation 23703 status: Accepted by Decision tree
# Simulation 23703 status: OK
# ********** Check convergence criteria **********
#
# Actual simulations so far: 1000
# All cluster are full with 1 times of the bandwidth of 0.0023
# ********** Convergence criteria not reached yet **********
#
#
# 0
# Simulation 23704 status: Discarded by Decision tree
# 1
# Simulation 23705 status: Accepted by Decision tree
# Simulation 23705 status: OK
# 1
# Simulation 23706 status: Accepted by Decision tree
# Simulation 23706 status: OK
# 0
# Simulation 23707 status: Discarded by Decision tree
# 0
# Simulation 23708 status: Discarded by Decision tree
# 0
# Simulation 23709 status: Discarded by Decision tree
# 0
# Simulation 23710 status: Discarded by Decision tree
# 0
# Simulation 23711 status: Discarded by Decision tree
# 0
# Simulation 23712 status: Discarded by Decision tree
# 0
# Simulation 23713 status: Discarded by Decision tree
# 0
# Simulation 23714 status: Discarded by Decision tree
# 0
# Simulation 23715 status: Discarded by Decision tree
# 0
# Simulation 23716 status: Discarded by Decision tree
# 1
# Simulation 23717 status: Accepted by Decision tree
# Simulation 23717 status: OK
# 0
# Simulation 23718 status: Discarded by Decision tree
# 0
# Simulation 23719 status: Discarded by Decision tree
# 0
# Simulation 23720 status: Discarded by Decision tree
# 0
# Simulation 23721 status: Discarded by Decision tree
# 0
# Simulation 23722 status: Discarded by Decision tree
# 0
# Simulation 23723 status: Discarded by Decision tree
# 0
# Simulation 23724 status: Discarded by Decision tree
# 0
# Simulation 23725 status: Discarded by Decision tree
# 0
# Simulation 23726 status: Discarded by Decision tree
# 0
# Simulation 23727 status: Discarded by Decision tree
# 0
# Simulation 23728 status: Discarded by Decision tree
# 0
# Simulation 23729 status: Discarded by Decision tree
# 0
# Simulation 23730 status: Discarded by Decision tree
# 0
# Simulation 23731 status: Discarded by Decision tree
# 0
# Simulation 23732 status: Discarded by Decision tree
# 0
# Simulation 23733 status: Discarded by Decision tree
# 1
# Simulation 23734 status: Accepted by Decision tree
# Simulation 23734 status: OK
# 0
# Simulation 23735 status: Discarded by Decision tree
# 0
# Simulation 23736 status: Discarded by Decision tree
# 0
# Simulation 23737 status: Discarded by Decision tree
# 0
# Simulation 23738 status: Discarded by Decision tree
# 0
# Simulation 23739 status: Discarded by Decision tree
# 0
# Simulation 23740 status: Discarded by Decision tree
# 0
# Simulation 23741 status: Discarded by Decision tree
# 0
# Simulation 23742 status: Discarded by Decision tree
# 0
# Simulation 23743 status: Discarded by Decision tree
# 0
# Simulation 23744 status: Discarded by Decision tree
# 1
# Simulation 23745 status: Accepted by Decision tree
# Simulation 23745 status: OK
# 0
# Simulation 23746 status: Discarded by Decision tree
# 0
# Simulation 23747 status: Discarded by Decision tree
# 0
# Simulation 23748 status: Discarded by Decision tree
# 0
# Simulation 23749 status: Discarded by Decision tree
# 0
# Simulation 23750 status: Discarded by Decision tree
# 0
# Simulation 23751 status: Discarded by Decision tree
# 0
# Simulation 23752 status: Discarded by Decision tree
# 0
# Simulation 23753 status: Discarded by Decision tree
# 0
# Simulation 23754 status: Discarded by Decision tree
# 0
# Simulation 23755 status: Discarded by Decision tree
# 0
# Simulation 23756 status: Discarded by Decision tree
# 0
# Simulation 23757 status: Discarded by Decision tree
# 0
# Simulation 23758 status: Discarded by Decision tree
# 0
# Simulation 23759 status: Discarded by Decision tree
# 0
# Simulation 23760 status: Discarded by Decision tree
# 0
# Simulation 23761 status: Discarded by Decision tree
# 0
# Simulation 23762 status: Discarded by Decision tree
# 0
# Simulation 23763 status: Discarded by Decision tree
# 0
# Simulation 23764 status: Discarded by Decision tree
# 0
# Simulation 23765 status: Discarded by Decision tree
# 0
# Simulation 23766 status: Discarded by Decision tree
# 0
# Simulation 23767 status: Discarded by Decision tree
# 0
# Simulation 23768 status: Discarded by Decision tree
# 1
# Simulation 23769 status: Accepted by Decision tree
# Simulation 23769 status: OK
# 0
# Simulation 23770 status: Discarded by Decision tree
# 0
# Simulation 23771 status: Discarded by Decision tree
# 0
# Simulation 23772 status: Discarded by Decision tree
# 0
# Simulation 23773 status: Discarded by Decision tree
# 0
# Simulation 23774 status: Discarded by Decision tree
# 0
# Simulation 23775 status: Discarded by Decision tree
# 0
# Simulation 23776 status: Discarded by Decision tree
# 0
# Simulation 23777 status: Discarded by Decision tree
# 0
# Simulation 23778 status: Discarded by Decision tree
# 0
# Simulation 23779 status: Discarded by Decision tree
# 0
# Simulation 23780 status: Discarded by Decision tree
# 0
# Simulation 23781 status: Discarded by Decision tree
# 0
# Simulation 23782 status: Discarded by Decision tree
# 1
# Simulation 23783 status: Accepted by Decision tree
# Simulation 23783 status: OK
# 0
# Simulation 23784 status: Discarded by Decision tree
# 0
# Simulation 23785 status: Discarded by Decision tree
# 0
# Simulation 23786 status: Discarded by Decision tree
# 0
# Simulation 23787 status: Discarded by Decision tree
# 0
# Simulation 23788 status: Discarded by Decision tree
# 0
# Simulation 23789 status: Discarded by Decision tree
# 0
# Simulation 23790 status: Discarded by Decision tree
# 0
# Simulation 23791 status: Discarded by Decision tree
# 0
# Simulation 23792 status: Discarded by Decision tree
# 0
# Simulation 23793 status: Discarded by Decision tree
# 0
# Simulation 23794 status: Discarded by Decision tree
# 0
# Simulation 23795 status: Discarded by Decision tree
# 0
# Simulation 23796 status: Discarded by Decision tree
# 0
# Simulation 23797 status: Discarded by Decision tree
# 0
# Simulation 23798 status: Discarded by Decision tree
# 1
# Simulation 23799 status: Accepted by Decision tree
# Simulation 23799 status: OK
# 0
# Simulation 23800 status: Discarded by Decision tree
# 1
# Simulation 23801 status: Accepted by Decision tree
# Simulation 23801 status: OK
# 0
# Simulation 23802 status: Discarded by Decision tree
# 0
# Simulation 23803 status: Discarded by Decision tree
# 0
# Simulation 23804 status: Discarded by Decision tree
# 0
# Simulation 23805 status: Discarded by Decision tree
# 0
# Simulation 23806 status: Discarded by Decision tree
# 0
# Simulation 23807 status: Discarded by Decision tree
# 0
# Simulation 23808 status: Discarded by Decision tree
# 0
# Simulation 23809 status: Discarded by Decision tree
# 0
# Simulation 23810 status: Discarded by Decision tree
# 0
# Simulation 23811 status: Discarded by Decision tree
# 1
# Simulation 23812 status: Accepted by Decision tree
# Simulation 23812 status: ErrorType Incompatible parameters set
# 0
# Simulation 23813 status: Discarded by Decision tree
# 0
# Simulation 23814 status: Discarded by Decision tree
# 0
# Simulation 23815 status: Discarded by Decision tree
# 0
# Simulation 23816 status: Discarded by Decision tree
# 0
# Simulation 23817 status: Discarded by Decision tree
# 0
# Simulation 23818 status: Discarded by Decision tree
# 0
# Simulation 23819 status: Discarded by Decision tree
# 0
# Simulation 23820 status: Discarded by Decision tree
# 0
# Simulation 23821 status: Discarded by Decision tree
# 0
# Simulation 23822 status: Discarded by Decision tree
# 0
# Simulation 23823 status: Discarded by Decision tree
# 0
# Simulation 23824 status: Discarded by Decision tree
# 0
# Simulation 23825 status: Discarded by Decision tree
# 1
# Simulation 23826 status: Accepted by Decision tree
# Simulation 23826 status: OK
# 0
# Simulation 23827 status: Discarded by Decision tree
# 0
# Simulation 23828 status: Discarded by Decision tree
# 0
# Simulation 23829 status: Discarded by Decision tree
# 0
# Simulation 23830 status: Discarded by Decision tree
# 1
# Simulation 23831 status: Accepted by Decision tree
# Simulation 23831 status: ErrorType Incompatible parameters set
# 0
# Simulation 23832 status: Discarded by Decision tree
# 0
# Simulation 23833 status: Discarded by Decision tree
# 0
# Simulation 23834 status: Discarded by Decision tree
# 0
# Simulation 23835 status: Discarded by Decision tree
# 0
# Simulation 23836 status: Discarded by Decision tree
# 0
# Simulation 23837 status: Discarded by Decision tree
# 0
# Simulation 23838 status: Discarded by Decision tree
# 0
# Simulation 23839 status: Discarded by Decision tree
# 0
# Simulation 23840 status: Discarded by Decision tree
# 0
# Simulation 23841 status: Discarded by Decision tree
# 0
# Simulation 23842 status: Discarded by Decision tree
# 0
# Simulation 23843 status: Discarded by Decision tree
# 1
# Simulation 23844 status: Accepted by Decision tree
# Simulation 23844 status: OK
# 0
# Simulation 23845 status: Discarded by Decision tree
# 0
# Simulation 23846 status: Discarded by Decision tree
# 0
# Simulation 23847 status: Discarded by Decision tree
# 0
# Simulation 23848 status: Discarded by Decision tree
# 0
# Simulation 23849 status: Discarded by Decision tree
# 0
# Simulation 23850 status: Discarded by Decision tree
# 0
# Simulation 23851 status: Discarded by Decision tree
# 0
# Simulation 23852 status: Discarded by Decision tree
# 0
# Simulation 23853 status: Discarded by Decision tree
# 0
# Simulation 23854 status: Discarded by Decision tree
# 0
# Simulation 23855 status: Discarded by Decision tree
# 0
# Simulation 23856 status: Discarded by Decision tree
# 0
# Simulation 23857 status: Discarded by Decision tree
# 0
# Simulation 23858 status: Discarded by Decision tree
# 0
# Simulation 23859 status: Discarded by Decision tree
# 0
# Simulation 23860 status: Discarded by Decision tree
# 1
# Simulation 23861 status: Accepted by Decision tree
# Simulation 23861 status: OK
# 0
# Simulation 23862 status: Discarded by Decision tree
# 0
# Simulation 23863 status: Discarded by Decision tree
# 0
# Simulation 23864 status: Discarded by Decision tree
# 0
# Simulation 23865 status: Discarded by Decision tree
# 0
# Simulation 23866 status: Discarded by Decision tree
# 0
# Simulation 23867 status: Discarded by Decision tree
# 0
# Simulation 23868 status: Discarded by Decision tree
# 0
# Simulation 23869 status: Discarded by Decision tree
# 0
# Simulation 23870 status: Discarded by Decision tree
# 0
# Simulation 23871 status: Discarded by Decision tree
# 0
# Simulation 23872 status: Discarded by Decision tree
# 0
# Simulation 23873 status: Discarded by Decision tree
# 0
# Simulation 23874 status: Discarded by Decision tree
# 0
# Simulation 23875 status: Discarded by Decision tree
# 0
# Simulation 23876 status: Discarded by Decision tree
# 0
# Simulation 23877 status: Discarded by Decision tree
# 0
# Simulation 23878 status: Discarded by Decision tree
# 0
# Simulation 23879 status: Discarded by Decision tree
# 0
# Simulation 23880 status: Discarded by Decision tree
# 0
# Simulation 23881 status: Discarded by Decision tree
# 0
# Simulation 23882 status: Discarded by Decision tree
# 1
# Simulation 23883 status: Accepted by Decision tree
# Simulation 23883 status: ErrorType Incompatible parameters set
# 0
# Simulation 23884 status: Discarded by Decision tree
# 0
# Simulation 23885 status: Discarded by Decision tree
# 0
# Simulation 23886 status: Discarded by Decision tree
# 0
# Simulation 23887 status: Discarded by Decision tree
# 0
# Simulation 23888 status: Discarded by Decision tree
# 0
# Simulation 23889 status: Discarded by Decision tree
# 0
# Simulation 23890 status: Discarded by Decision tree
# 0
# Simulation 23891 status: Discarded by Decision tree
# 0
# Simulation 23892 status: Discarded by Decision tree
# 0
# Simulation 23893 status: Discarded by Decision tree
# 0
# Simulation 23894 status: Discarded by Decision tree
# 1
# Simulation 23895 status: Accepted by Decision tree
# Simulation 23895 status: OK
# 0
# Simulation 23896 status: Discarded by Decision tree
# 0
# Simulation 23897 status: Discarded by Decision tree
# 0
# Simulation 23898 status: Discarded by Decision tree
# 0
# Simulation 23899 status: Discarded by Decision tree
# 0
# Simulation 23900 status: Discarded by Decision tree
# 0
# Simulation 23901 status: Discarded by Decision tree
# 0
# Simulation 23902 status: Discarded by Decision tree
# 0
# Simulation 23903 status: Discarded by Decision tree
# 0
# Simulation 23904 status: Discarded by Decision tree
# 0
# Simulation 23905 status: Discarded by Decision tree
# 0
# Simulation 23906 status: Discarded by Decision tree
# 0
# Simulation 23907 status: Discarded by Decision tree
# 0
# Simulation 23908 status: Discarded by Decision tree
# 1
# Simulation 23909 status: Accepted by Decision tree
# Simulation 23909 status: OK
# 0
# Simulation 23910 status: Discarded by Decision tree
# 1
# Simulation 23911 status: Accepted by Decision tree
# Simulation 23911 status: OK
# 0
# Simulation 23912 status: Discarded by Decision tree
# 0
# Simulation 23913 status: Discarded by Decision tree
# 0
# Simulation 23914 status: Discarded by Decision tree
# 0
# Simulation 23915 status: Discarded by Decision tree
# 0
# Simulation 23916 status: Discarded by Decision tree
# 0
# Simulation 23917 status: Discarded by Decision tree
# 0
# Simulation 23918 status: Discarded by Decision tree
# 0
# Simulation 23919 status: Discarded by Decision tree
# 0
# Simulation 23920 status: Discarded by Decision tree
# 0
# Simulation 23921 status: Discarded by Decision tree
# 0
# Simulation 23922 status: Discarded by Decision tree
# 0
# Simulation 23923 status: Discarded by Decision tree
# 0
# Simulation 23924 status: Discarded by Decision tree
# 0
# Simulation 23925 status: Discarded by Decision tree
# 0
# Simulation 23926 status: Discarded by Decision tree
# 1
# Simulation 23927 status: Accepted by Decision tree
# Simulation 23927 status: OK
# 0
# Simulation 23928 status: Discarded by Decision tree
# 0
# Simulation 23929 status: Discarded by Decision tree
# 0
# Simulation 23930 status: Discarded by Decision tree
# 0
# Simulation 23931 status: Discarded by Decision tree
# 0
# Simulation 23932 status: Discarded by Decision tree
# 0
# Simulation 23933 status: Discarded by Decision tree
# 0
# Simulation 23934 status: Discarded by Decision tree
# 0
# Simulation 23935 status: Discarded by Decision tree
# 0
# Simulation 23936 status: Discarded by Decision tree
# 0
# Simulation 23937 status: Discarded by Decision tree
# 0
# Simulation 23938 status: Discarded by Decision tree
# 0
# Simulation 23939 status: Discarded by Decision tree
# 0
# Simulation 23940 status: Discarded by Decision tree
# 1
# Simulation 23941 status: Accepted by Decision tree
# Simulation 23941 status: OK
# 0
# Simulation 23942 status: Discarded by Decision tree
# 0
# Simulation 23943 status: Discarded by Decision tree
# 0
# Simulation 23944 status: Discarded by Decision tree
# 0
# Simulation 23945 status: Discarded by Decision tree
# 0
# Simulation 23946 status: Discarded by Decision tree
# 0
# Simulation 23947 status: Discarded by Decision tree
# 0
# Simulation 23948 status: Discarded by Decision tree
# 0
# Simulation 23949 status: Discarded by Decision tree
# 0
# Simulation 23950 status: Discarded by Decision tree
# 0
# Simulation 23951 status: Discarded by Decision tree
# 0
# Simulation 23952 status: Discarded by Decision tree
# 0
# Simulation 23953 status: Discarded by Decision tree
# 0
# Simulation 23954 status: Discarded by Decision tree
# 0
# Simulation 23955 status: Discarded by Decision tree
# 0
# Simulation 23956 status: Discarded by Decision tree
# 0
# Simulation 23957 status: Discarded by Decision tree
# 0
# Simulation 23958 status: Discarded by Decision tree
# 0
# Simulation 23959 status: Discarded by Decision tree
# 1
# Simulation 23960 status: Accepted by Decision tree
# Simulation 23960 status: OK
# 0
# Simulation 23961 status: Discarded by Decision tree
# 0
# Simulation 23962 status: Discarded by Decision tree
# 0
# Simulation 23963 status: Discarded by Decision tree
# 0
# Simulation 23964 status: Discarded by Decision tree
# 0
# Simulation 23965 status: Discarded by Decision tree
# 0
# Simulation 23966 status: Discarded by Decision tree
# 0
# Simulation 23967 status: Discarded by Decision tree
# 0
# Simulation 23968 status: Discarded by Decision tree
# 0
# Simulation 23969 status: Discarded by Decision tree
# 0
# Simulation 23970 status: Discarded by Decision tree
# 0
# Simulation 23971 status: Discarded by Decision tree
# 0
# Simulation 23972 status: Discarded by Decision tree
# 0
# Simulation 23973 status: Discarded by Decision tree
# 0
# Simulation 23974 status: Discarded by Decision tree
# 0
# Simulation 23975 status: Discarded by Decision tree
# 0
# Simulation 23976 status: Discarded by Decision tree
# 0
# Simulation 23977 status: Discarded by Decision tree
# 0
# Simulation 23978 status: Discarded by Decision tree
# 0
# Simulation 23979 status: Discarded by Decision tree
# 0
# Simulation 23980 status: Discarded by Decision tree
# 0
# Simulation 23981 status: Discarded by Decision tree
# 0
# Simulation 23982 status: Discarded by Decision tree
# 0
# Simulation 23983 status: Discarded by Decision tree
# 0
# Simulation 23984 status: Discarded by Decision tree
# 1
# Simulation 23985 status: Accepted by Decision tree
# Simulation 23985 status: OK
# 0
# Simulation 23986 status: Discarded by Decision tree
# 0
# Simulation 23987 status: Discarded by Decision tree
# 0
# Simulation 23988 status: Discarded by Decision tree
# 0
# Simulation 23989 status: Discarded by Decision tree
# 0
# Simulation 23990 status: Discarded by Decision tree
# 0
# Simulation 23991 status: Discarded by Decision tree
# 0
# Simulation 23992 status: Discarded by Decision tree
# 0
# Simulation 23993 status: Discarded by Decision tree
# 0
# Simulation 23994 status: Discarded by Decision tree
# 0
# Simulation 23995 status: Discarded by Decision tree
# 0
# Simulation 23996 status: Discarded by Decision tree
# 0
# Simulation 23997 status: Discarded by Decision tree
# 0
# Simulation 23998 status: Discarded by Decision tree
# 0
# Simulation 23999 status: Discarded by Decision tree
# 1
# Simulation 24000 status: Accepted by Decision tree
# Simulation 24000 status: OK
# 0
# Simulation 24001 status: Discarded by Decision tree
# 0
# Simulation 24002 status: Discarded by Decision tree
# 0
# Simulation 24003 status: Discarded by Decision tree
# 0
# Simulation 24004 status: Discarded by Decision tree
# 0
# Simulation 24005 status: Discarded by Decision tree
# 0
# Simulation 24006 status: Discarded by Decision tree
# 0
# Simulation 24007 status: Discarded by Decision tree
# 1
# Simulation 24008 status: Accepted by Decision tree
# Simulation 24008 status: OK
# 0
# Simulation 24009 status: Discarded by Decision tree
# 0
# Simulation 24010 status: Discarded by Decision tree
# 0
# Simulation 24011 status: Discarded by Decision tree
# 0
# Simulation 24012 status: Discarded by Decision tree
# 0
# Simulation 24013 status: Discarded by Decision tree
# 0
# Simulation 24014 status: Discarded by Decision tree
# 0
# Simulation 24015 status: Discarded by Decision tree
# 0
# Simulation 24016 status: Discarded by Decision tree
# 0
# Simulation 24017 status: Discarded by Decision tree
# 0
# Simulation 24018 status: Discarded by Decision tree
# 0
# Simulation 24019 status: Discarded by Decision tree
# 0
# Simulation 24020 status: Discarded by Decision tree
# 0
# Simulation 24021 status: Discarded by Decision tree
# 0
# Simulation 24022 status: Discarded by Decision tree
# 0
# Simulation 24023 status: Discarded by Decision tree
# 0
# Simulation 24024 status: Discarded by Decision tree
# 0
# Simulation 24025 status: Discarded by Decision tree
# 0
# Simulation 24026 status: Discarded by Decision tree
# 0
# Simulation 24027 status: Discarded by Decision tree
# 0
# Simulation 24028 status: Discarded by Decision tree
# 0
# Simulation 24029 status: Discarded by Decision tree
# 0
# Simulation 24030 status: Discarded by Decision tree
# 0
# Simulation 24031 status: Discarded by Decision tree
# 1
# Simulation 24032 status: Accepted by Decision tree
# Simulation 24032 status: OK
# 0
# Simulation 24033 status: Discarded by Decision tree
# 0
# Simulation 24034 status: Discarded by Decision tree
# 0
# Simulation 24035 status: Discarded by Decision tree
# 0
# Simulation 24036 status: Discarded by Decision tree
# 0
# Simulation 24037 status: Discarded by Decision tree
# 0
# Simulation 24038 status: Discarded by Decision tree
# 0
# Simulation 24039 status: Discarded by Decision tree
# 0
# Simulation 24040 status: Discarded by Decision tree
# 0
# Simulation 24041 status: Discarded by Decision tree
# 0
# Simulation 24042 status: Discarded by Decision tree
# 0
# Simulation 24043 status: Discarded by Decision tree
# 0
# Simulation 24044 status: Discarded by Decision tree
# 0
# Simulation 24045 status: Discarded by Decision tree
# 0
# Simulation 24046 status: Discarded by Decision tree
# 1
# Simulation 24047 status: Accepted by Decision tree
# Simulation 24047 status: OK
# 0
# Simulation 24048 status: Discarded by Decision tree
# 0
# Simulation 24049 status: Discarded by Decision tree
# 0
# Simulation 24050 status: Discarded by Decision tree
# 0
# Simulation 24051 status: Discarded by Decision tree
# 0
# Simulation 24052 status: Discarded by Decision tree
# 0
# Simulation 24053 status: Discarded by Decision tree
# 0
# Simulation 24054 status: Discarded by Decision tree
# 0
# Simulation 24055 status: Discarded by Decision tree
# 0
# Simulation 24056 status: Discarded by Decision tree
# 0
# Simulation 24057 status: Discarded by Decision tree
# 0
# Simulation 24058 status: Discarded by Decision tree
# 0
# Simulation 24059 status: Discarded by Decision tree
# 0
# Simulation 24060 status: Discarded by Decision tree
# 0
# Simulation 24061 status: Discarded by Decision tree
# 0
# Simulation 24062 status: Discarded by Decision tree
# 0
# Simulation 24063 status: Discarded by Decision tree
# 0
# Simulation 24064 status: Discarded by Decision tree
# 0
# Simulation 24065 status: Discarded by Decision tree
# 0
# Simulation 24066 status: Discarded by Decision tree
# 0
# Simulation 24067 status: Discarded by Decision tree
# 0
# Simulation 24068 status: Discarded by Decision tree
# 0
# Simulation 24069 status: Discarded by Decision tree
# 0
# Simulation 24070 status: Discarded by Decision tree
# 0
# Simulation 24071 status: Discarded by Decision tree
# 0
# Simulation 24072 status: Discarded by Decision tree
# 0
# Simulation 24073 status: Discarded by Decision tree
# 0
# Simulation 24074 status: Discarded by Decision tree
# 0
# Simulation 24075 status: Discarded by Decision tree
# 0
# Simulation 24076 status: Discarded by Decision tree
# 0
# Simulation 24077 status: Discarded by Decision tree
# 0
# Simulation 24078 status: Discarded by Decision tree
# 0
# Simulation 24079 status: Discarded by Decision tree
# 0
# Simulation 24080 status: Discarded by Decision tree
# 0
# Simulation 24081 status: Discarded by Decision tree
# 0
# Simulation 24082 status: Discarded by Decision tree
# 0
# Simulation 24083 status: Discarded by Decision tree
# 0
# Simulation 24084 status: Discarded by Decision tree
# 0
# Simulation 24085 status: Discarded by Decision tree
# 0
# Simulation 24086 status: Discarded by Decision tree
# 0
# Simulation 24087 status: Discarded by Decision tree
# 0
# Simulation 24088 status: Discarded by Decision tree
# 0
# Simulation 24089 status: Discarded by Decision tree
# 0
# Simulation 24090 status: Discarded by Decision tree
# 0
# Simulation 24091 status: Discarded by Decision tree
# 1
# Simulation 24092 status: Accepted by Decision tree
# Simulation 24092 status: ErrorType Incompatible parameters set
# 0
# Simulation 24093 status: Discarded by Decision tree
# 0
# Simulation 24094 status: Discarded by Decision tree
# 0
# Simulation 24095 status: Discarded by Decision tree
# 0
# Simulation 24096 status: Discarded by Decision tree
# 0
# Simulation 24097 status: Discarded by Decision tree
# 0
# Simulation 24098 status: Discarded by Decision tree
# 0
# Simulation 24099 status: Discarded by Decision tree
# 0
# Simulation 24100 status: Discarded by Decision tree
# 0
# Simulation 24101 status: Discarded by Decision tree
# 0
# Simulation 24102 status: Discarded by Decision tree
# 0
# Simulation 24103 status: Discarded by Decision tree
# 0
# Simulation 24104 status: Discarded by Decision tree
# 0
# Simulation 24105 status: Discarded by Decision tree
# 0
# Simulation 24106 status: Discarded by Decision tree
# 0
# Simulation 24107 status: Discarded by Decision tree
# 0
# Simulation 24108 status: Discarded by Decision tree
# 0
# Simulation 24109 status: Discarded by Decision tree
# 0
# Simulation 24110 status: Discarded by Decision tree
# 0
# Simulation 24111 status: Discarded by Decision tree
# 0
# Simulation 24112 status: Discarded by Decision tree
# 0
# Simulation 24113 status: Discarded by Decision tree
# 0
# Simulation 24114 status: Discarded by Decision tree
# 0
# Simulation 24115 status: Discarded by Decision tree
# 0
# Simulation 24116 status: Discarded by Decision tree
# 0
# Simulation 24117 status: Discarded by Decision tree
# 0
# Simulation 24118 status: Discarded by Decision tree
# 0
# Simulation 24119 status: Discarded by Decision tree
# 0
# Simulation 24120 status: Discarded by Decision tree
# 0
# Simulation 24121 status: Discarded by Decision tree
# 0
# Simulation 24122 status: Discarded by Decision tree
# 0
# Simulation 24123 status: Discarded by Decision tree
# 0
# Simulation 24124 status: Discarded by Decision tree
# 0
# Simulation 24125 status: Discarded by Decision tree
# 0
# Simulation 24126 status: Discarded by Decision tree
# 0
# Simulation 24127 status: Discarded by Decision tree
# 0
# Simulation 24128 status: Discarded by Decision tree
# 0
# Simulation 24129 status: Discarded by Decision tree
# 0
# Simulation 24130 status: Discarded by Decision tree
# 0
# Simulation 24131 status: Discarded by Decision tree
# 0
# Simulation 24132 status: Discarded by Decision tree
# 0
# Simulation 24133 status: Discarded by Decision tree
# 0
# Simulation 24134 status: Discarded by Decision tree
# 0
# Simulation 24135 status: Discarded by Decision tree
# 0
# Simulation 24136 status: Discarded by Decision tree
# 0
# Simulation 24137 status: Discarded by Decision tree
# 0
# Simulation 24138 status: Discarded by Decision tree
# 0
# Simulation 24139 status: Discarded by Decision tree
# 0
# Simulation 24140 status: Discarded by Decision tree
# 0
# Simulation 24141 status: Discarded by Decision tree
# 1
# Simulation 24142 status: Accepted by Decision tree
# Simulation 24142 status: OK
# 0
# Simulation 24143 status: Discarded by Decision tree
# 0
# Simulation 24144 status: Discarded by Decision tree
# 0
# Simulation 24145 status: Discarded by Decision tree
# 0
# Simulation 24146 status: Discarded by Decision tree
# 0
# Simulation 24147 status: Discarded by Decision tree
# 0
# Simulation 24148 status: Discarded by Decision tree
# 0
# Simulation 24149 status: Discarded by Decision tree
# 0
# Simulation 24150 status: Discarded by Decision tree
# 0
# Simulation 24151 status: Discarded by Decision tree
# 0
# Simulation 24152 status: Discarded by Decision tree
# 0
# Simulation 24153 status: Discarded by Decision tree
# 0
# Simulation 24154 status: Discarded by Decision tree
# 0
# Simulation 24155 status: Discarded by Decision tree
# 0
# Simulation 24156 status: Discarded by Decision tree
# 1
# Simulation 24157 status: Accepted by Decision tree
# Simulation 24157 status: OK
# 0
# Simulation 24158 status: Discarded by Decision tree
# 0
# Simulation 24159 status: Discarded by Decision tree
# 0
# Simulation 24160 status: Discarded by Decision tree
# 0
# Simulation 24161 status: Discarded by Decision tree
# 0
# Simulation 24162 status: Discarded by Decision tree
# 0
# Simulation 24163 status: Discarded by Decision tree
# 0
# Simulation 24164 status: Discarded by Decision tree
# 0
# Simulation 24165 status: Discarded by Decision tree
# 0
# Simulation 24166 status: Discarded by Decision tree
# 0
# Simulation 24167 status: Discarded by Decision tree
# 0
# Simulation 24168 status: Discarded by Decision tree
# 1
# Simulation 24169 status: Accepted by Decision tree
# Simulation 24169 status: OK
# 0
# Simulation 24170 status: Discarded by Decision tree
# 0
# Simulation 24171 status: Discarded by Decision tree
# 0
# Simulation 24172 status: Discarded by Decision tree
# 0
# Simulation 24173 status: Discarded by Decision tree
# 0
# Simulation 24174 status: Discarded by Decision tree
# 0
# Simulation 24175 status: Discarded by Decision tree
# 0
# ...
# 0
# Simulation 25466 status: Discarded by Decision tree
# 0
# Simulation 25467 status: Discarded by Decision tree
# 0
# Simulation 25468 status: Discarded by Decision tree
# 0
# Simulation 25469 status: Discarded by Decision tree
# 1
# Simulation 25470 status: Accepted by Decision tree
# Simulation 25470 status: OK
# 0
# Simulation 25471 status: Discarded by Decision tree
# 0
# Simulation 25472 status: Discarded by Decision tree
# 0
# Simulation 25473 status: Discarded by Decision tree
# 0
# Simulation 25474 status: Discarded by Decision tree
# 0
# Simulation 25475 status: Discarded by Decision tree
# 0
# Simulation 25476 status: Discarded by Decision tree
# 0
# Simulation 25477 status: Discarded by Decision tree
# 1
# Simulation 25478 status: Accepted by Decision tree
# Simulation 25478 status: OK
# 0
# Simulation 25479 status: Discarded by Decision tree
# 0
# Simulation 25480 status: Discarded by Decision tree
# 0
# Simulation 25481 status: Discarded by Decision tree
# 0
# Simulation 25482 status: Discarded by Decision tree
# 0
# Simulation 25483 status: Discarded by Decision tree
# 0
# Simulation 25484 status: Discarded by Decision tree
# 0
# Simulation 25485 status: Discarded by Decision tree
# 0
# Simulation 25486 status: Discarded by Decision tree
# 0
# Simulation 25487 status: Discarded by Decision tree
# 0
# Simulation 25488 status: Discarded by Decision tree
# 0
# Simulation 25489 status: Discarded by Decision tree
# 0
# Simulation 25490 status: Discarded by Decision tree
# 0
# Simulation 25491 status: Discarded by Decision tree
# 0
# Simulation 25492 status: Discarded by Decision tree
# 0
# Simulation 25493 status: Discarded by Decision tree
# 0
# Simulation 25494 status: Discarded by Decision tree
# 0
# Simulation 25495 status: Discarded by Decision tree
# 0
# Simulation 25496 status: Discarded by Decision tree
# 0
# Simulation 25497 status: Discarded by Decision tree
# 0
# Simulation 25498 status: Discarded by Decision tree
# 0
# Simulation 25499 status: Discarded by Decision tree
# 0
# Simulation 25500 status: Discarded by Decision tree
# 0
# Simulation 25501 status: Discarded by Decision tree
# 0
# Simulation 25502 status: Discarded by Decision tree
# 1
# Simulation 25503 status: Accepted by Decision tree
# Simulation 25503 status: OK
# 0
# Simulation 25504 status: Discarded by Decision tree
# 0
# Simulation 25505 status: Discarded by Decision tree
# 0
# Simulation 25506 status: Discarded by Decision tree
# 0
# Simulation 25507 status: Discarded by Decision tree
# 0
# Simulation 25508 status: Discarded by Decision tree
# 0
# Simulation 25509 status: Discarded by Decision tree
# 0
# Simulation 25510 status: Discarded by Decision tree
# 0
# Simulation 25511 status: Discarded by Decision tree
# 0
# Simulation 25512 status: Discarded by Decision tree
# 1
# Simulation 25513 status: Accepted by Decision tree
# Simulation 25513 status: OK
# 0
# Simulation 25514 status: Discarded by Decision tree
# 0
# Simulation 25515 status: Discarded by Decision tree
# 0
# Simulation 25516 status: Discarded by Decision tree
# 0
# Simulation 25517 status: Discarded by Decision tree
# 0
# Simulation 25518 status: Discarded by Decision tree
# 0
# Simulation 25519 status: Discarded by Decision tree
# 1
# Simulation 25520 status: Accepted by Decision tree
# Simulation 25520 status: ErrorType Incompatible parameters set
# 0
# Simulation 25521 status: Discarded by Decision tree
# 0
# Simulation 25522 status: Discarded by Decision tree
# 0
# Simulation 25523 status: Discarded by Decision tree
# 0
# Simulation 25524 status: Discarded by Decision tree
# 0
# Simulation 25525 status: Discarded by Decision tree
# 0
# Simulation 25526 status: Discarded by Decision tree
# 0
# Simulation 25527 status: Discarded by Decision tree
# 0
# Simulation 25528 status: Discarded by Decision tree
# 0
# Simulation 25529 status: Discarded by Decision tree
# 0
# Simulation 25530 status: Discarded by Decision tree
# 0
# Simulation 25531 status: Discarded by Decision tree
# 0
# Simulation 25532 status: Discarded by Decision tree
# 0
# Simulation 25533 status: Discarded by Decision tree
# 0
# Simulation 25534 status: Discarded by Decision tree
# 0
# Simulation 25535 status: Discarded by Decision tree
# 0
# Simulation 25536 status: Discarded by Decision tree
# 0
# Simulation 25537 status: Discarded by Decision tree
# 0
# Simulation 25538 status: Discarded by Decision tree
# 0
# Simulation 25539 status: Discarded by Decision tree
# 0
# Simulation 25540 status: Discarded by Decision tree
# 0
# Simulation 25541 status: Discarded by Decision tree
# 0
# Simulation 25542 status: Discarded by Decision tree
# 0
# Simulation 25543 status: Discarded by Decision tree
# 0
# Simulation 25544 status: Discarded by Decision tree
# 0
# Simulation 25545 status: Discarded by Decision tree
# 0
# Simulation 25546 status: Discarded by Decision tree
# 0
# Simulation 25547 status: Discarded by Decision tree
# 0
# Simulation 25548 status: Discarded by Decision tree
# 0
# Simulation 25549 status: Discarded by Decision tree
# 0
# Simulation 25550 status: Discarded by Decision tree
# 0
# Simulation 25551 status: Discarded by Decision tree
# 0
# Simulation 25552 status: Discarded by Decision tree
# 0
# Simulation 25553 status: Discarded by Decision tree
# 0
# Simulation 25554 status: Discarded by Decision tree
# 0
# Simulation 25555 status: Discarded by Decision tree
# 0
# Simulation 25556 status: Discarded by Decision tree
# 0
# Simulation 25557 status: Discarded by Decision tree
# 0
# Simulation 25558 status: Discarded by Decision tree
# 0
# Simulation 25559 status: Discarded by Decision tree
# 0
# Simulation 25560 status: Discarded by Decision tree
# 0
# Simulation 25561 status: Discarded by Decision tree
# 0
# Simulation 25562 status: Discarded by Decision tree
# 0
# Simulation 25563 status: Discarded by Decision tree
# 0
# Simulation 25564 status: Discarded by Decision tree
# 0
# Simulation 25565 status: Discarded by Decision tree
# 0
# Simulation 25566 status: Discarded by Decision tree
# 0
# Simulation 25567 status: Discarded by Decision tree
# 0
# Simulation 25568 status: Discarded by Decision tree
# 0
# Simulation 25569 status: Discarded by Decision tree
# 0
# Simulation 25570 status: Discarded by Decision tree
# 0
# Simulation 25571 status: Discarded by Decision tree
# 0
# Simulation 25572 status: Discarded by Decision tree
# 0
# Simulation 25573 status: Discarded by Decision tree
# 0
# Simulation 25574 status: Discarded by Decision tree
# 0
# Simulation 25575 status: Discarded by Decision tree
# 0
# Simulation 25576 status: Discarded by Decision tree
# 0
# Simulation 25577 status: Discarded by Decision tree
# 0
# Simulation 25578 status: Discarded by Decision tree
# 0
# Simulation 25579 status: Discarded by Decision tree
# 0
# Simulation 25580 status: Discarded by Decision tree
# 0
# Simulation 25581 status: Discarded by Decision tree
# 0
# Simulation 25582 status: Discarded by Decision tree
# 0
# Simulation 25583 status: Discarded by Decision tree
# 0
# Simulation 25584 status: Discarded by Decision tree
# 0
# Simulation 25585 status: Discarded by Decision tree
# 0
# Simulation 25586 status: Discarded by Decision tree
# 0
# Simulation 25587 status: Discarded by Decision tree
# 0
# Simulation 25588 status: Discarded by Decision tree
# 0
# Simulation 25589 status: Discarded by Decision tree
# 0
# Simulation 25590 status: Discarded by Decision tree
# 0
# Simulation 25591 status: Discarded by Decision tree
# 0
# Simulation 25592 status: Discarded by Decision tree
# 0
# Simulation 25593 status: Discarded by Decision tree
# 0
# Simulation 25594 status: Discarded by Decision tree
# 0
# Simulation 25595 status: Discarded by Decision tree
# 0
# Simulation 25596 status: Discarded by Decision tree
# 0
# Simulation 25597 status: Discarded by Decision tree
# 0
# Simulation 25598 status: Discarded by Decision tree
# 0
# Simulation 25599 status: Discarded by Decision tree
# 0
# Simulation 25600 status: Discarded by Decision tree
# 0
# Simulation 25601 status: Discarded by Decision tree
# 0
# Simulation 25602 status: Discarded by Decision tree
# 0
# Simulation 25603 status: Discarded by Decision tree
# 0
# Simulation 25604 status: Discarded by Decision tree
# 0
# Simulation 25605 status: Discarded by Decision tree
# 0
# Simulation 25606 status: Discarded by Decision tree
# 0
# Simulation 25607 status: Discarded by Decision tree
# 0
# Simulation 25608 status: Discarded by Decision tree
# 0
# Simulation 25609 status: Discarded by Decision tree
# 0
# Simulation 25610 status: Discarded by Decision tree
# 0
# Simulation 25611 status: Discarded by Decision tree
# 0
# Simulation 25612 status: Discarded by Decision tree
# 0
# Simulation 25613 status: Discarded by Decision tree
# 0
# Simulation 25614 status: Discarded by Decision tree
# 0
# Simulation 25615 status: Discarded by Decision tree
# 0
# Simulation 25616 status: Discarded by Decision tree
# 1
# Simulation 25617 status: Accepted by Decision tree
# Simulation 25617 status: OK
# 0
# Simulation 25618 status: Discarded by Decision tree
# 0
# Simulation 25619 status: Discarded by Decision tree
# 0
# Simulation 25620 status: Discarded by Decision tree
# 0
# Simulation 25621 status: Discarded by Decision tree
# 0
# Simulation 25622 status: Discarded by Decision tree
# 0
# Simulation 25623 status: Discarded by Decision tree
# 0
# Simulation 25624 status: Discarded by Decision tree
# 0
# Simulation 25625 status: Discarded by Decision tree
# 0
# Simulation 25626 status: Discarded by Decision tree
# 0
# Simulation 25627 status: Discarded by Decision tree
# 0
# Simulation 25628 status: Discarded by Decision tree
# 1
# Simulation 25629 status: Accepted by Decision tree
# Simulation 25629 status: OK
# 0
# Simulation 25630 status: Discarded by Decision tree
# 0
# Simulation 25631 status: Discarded by Decision tree
# 0
# Simulation 25632 status: Discarded by Decision tree
# 0
# Simulation 25633 status: Discarded by Decision tree
# 0
# Simulation 25634 status: Discarded by Decision tree
# 0
# Simulation 25635 status: Discarded by Decision tree
# 0
# Simulation 25636 status: Discarded by Decision tree
# 0
# Simulation 25637 status: Discarded by Decision tree
# 0
# Simulation 25638 status: Discarded by Decision tree
# 0
# Simulation 25639 status: Discarded by Decision tree
# 0
# Simulation 25640 status: Discarded by Decision tree
# 0
# Simulation 25641 status: Discarded by Decision tree
# 0
# Simulation 25642 status: Discarded by Decision tree
# 0
# Simulation 25643 status: Discarded by Decision tree
# 0
# Simulation 25644 status: Discarded by Decision tree
# 0
# Simulation 25645 status: Discarded by Decision tree
# 0
# Simulation 25646 status: Discarded by Decision tree
# 0
# Simulation 25647 status: Discarded by Decision tree
# 0
# Simulation 25648 status: Discarded by Decision tree
# 0
# Simulation 25649 status: Discarded by Decision tree
# 1
# Simulation 25650 status: Accepted by Decision tree
# Simulation 25650 status: OK
# 0
# Simulation 25651 status: Discarded by Decision tree
# 0
# Simulation 25652 status: Discarded by Decision tree
# 0
# Simulation 25653 status: Discarded by Decision tree
# 1
# Simulation 25654 status: Accepted by Decision tree
# Simulation 25654 status: ErrorType Incompatible parameters set
# 0
# Simulation 25655 status: Discarded by Decision tree
# 0
# Simulation 25656 status: Discarded by Decision tree
# 0
# Simulation 25657 status: Discarded by Decision tree
# 0
# Simulation 25658 status: Discarded by Decision tree
# 0
# Simulation 25659 status: Discarded by Decision tree
# 0
# Simulation 25660 status: Discarded by Decision tree
# 0
# Simulation 25661 status: Discarded by Decision tree
# 0
# Simulation 25662 status: Discarded by Decision tree
# 0
# Simulation 25663 status: Discarded by Decision tree
# 0
# Simulation 25664 status: Discarded by Decision tree
# 0
# Simulation 25665 status: Discarded by Decision tree
# 0
# Simulation 25666 status: Discarded by Decision tree
# 0
# Simulation 25667 status: Discarded by Decision tree
# 0
# Simulation 25668 status: Discarded by Decision tree
# 0
# Simulation 25669 status: Discarded by Decision tree
# 0
# Simulation 25670 status: Discarded by Decision tree
# 0
# Simulation 25671 status: Discarded by Decision tree
# 0
# Simulation 25672 status: Discarded by Decision tree
# 0
# Simulation 25673 status: Discarded by Decision tree
# 0
# Simulation 25674 status: Discarded by Decision tree
# 0
# Simulation 25675 status: Discarded by Decision tree
# 0
# Simulation 25676 status: Discarded by Decision tree
# 0
# Simulation 25677 status: Discarded by Decision tree
# 0
# Simulation 25678 status: Discarded by Decision tree
# 0
# Simulation 25679 status: Discarded by Decision tree
# 0
# Simulation 25680 status: Discarded by Decision tree
# 0
# Simulation 25681 status: Discarded by Decision tree
# 0
# Simulation 25682 status: Discarded by Decision tree
# 0
# Simulation 25683 status: Discarded by Decision tree
# 0
# Simulation 25684 status: Discarded by Decision tree
# 0
# Simulation 25685 status: Discarded by Decision tree
# 0
# Simulation 25686 status: Discarded by Decision tree
# 0
# Simulation 25687 status: Discarded by Decision tree
# 0
# Simulation 25688 status: Discarded by Decision tree
# 0
# Simulation 25689 status: Discarded by Decision tree
# 0
# Simulation 25690 status: Discarded by Decision tree
# 0
# Simulation 25691 status: Discarded by Decision tree
# 0
# Simulation 25692 status: Discarded by Decision tree
# 0
# Simulation 25693 status: Discarded by Decision tree
# 0
# Simulation 25694 status: Discarded by Decision tree
# 1
# Simulation 25695 status: Accepted by Decision tree
# Simulation 25695 status: OK
# 1
# Simulation 25696 status: Accepted by Decision tree
# Simulation 25696 status: OK
# 0
# Simulation 25697 status: Discarded by Decision tree
# 0
# Simulation 25698 status: Discarded by Decision tree
# 0
# Simulation 25699 status: Discarded by Decision tree
# 1
# Simulation 25700 status: Accepted by Decision tree
# Simulation 25700 status: OK
# 0
# Simulation 25701 status: Discarded by Decision tree
# 0
# Simulation 25702 status: Discarded by Decision tree
# 0
# Simulation 25703 status: Discarded by Decision tree
# 0
# Simulation 25704 status: Discarded by Decision tree
# 0
# Simulation 25705 status: Discarded by Decision tree
# 0
# Simulation 25706 status: Discarded by Decision tree
# 0
# Simulation 25707 status: Discarded by Decision tree
# 0
# Simulation 25708 status: Discarded by Decision tree
# 0
# Simulation 25709 status: Discarded by Decision tree
# 0
# Simulation 25710 status: Discarded by Decision tree
# 0
# Simulation 25711 status: Discarded by Decision tree
# 1
# Simulation 25712 status: Accepted by Decision tree
# Simulation 25712 status: OK
# 0
# Simulation 25713 status: Discarded by Decision tree
# 0
# Simulation 25714 status: Discarded by Decision tree
# 0
# Simulation 25715 status: Discarded by Decision tree
# 0
# Simulation 25716 status: Discarded by Decision tree
# 0
# Simulation 25717 status: Discarded by Decision tree
# 0
# Simulation 25718 status: Discarded by Decision tree
# 0
# Simulation 25719 status: Discarded by Decision tree
# 0
# Simulation 25720 status: Discarded by Decision tree
# 0
# Simulation 25721 status: Discarded by Decision tree
# 0
# Simulation 25722 status: Discarded by Decision tree
# 0
# Simulation 25723 status: Discarded by Decision tree
# 0
# Simulation 25724 status: Discarded by Decision tree
# 0
# Simulation 25725 status: Discarded by Decision tree
# 0
# Simulation 25726 status: Discarded by Decision tree
# 0
# Simulation 25727 status: Discarded by Decision tree
# 0
# Simulation 25728 status: Discarded by Decision tree
# 0
# Simulation 25729 status: Discarded by Decision tree
# 0
# Simulation 25730 status: Discarded by Decision tree
# 0
# Simulation 25731 status: Discarded by Decision tree
# 0
# Simulation 25732 status: Discarded by Decision tree
# 0
# Simulation 25733 status: Discarded by Decision tree
# 0
# Simulation 25734 status: Discarded by Decision tree
# 0
# Simulation 25735 status: Discarded by Decision tree
# 0
# Simulation 25736 status: Discarded by Decision tree
# 0
# Simulation 25737 status: Discarded by Decision tree
# 1
# Simulation 25738 status: Accepted by Decision tree
# Simulation 25738 status: OK
# 0
# Simulation 25739 status: Discarded by Decision tree
# 0
# Simulation 25740 status: Discarded by Decision tree
# 0
# Simulation 25741 status: Discarded by Decision tree
# 1
# Simulation 25742 status: Accepted by Decision tree
# Simulation 25742 status: OK
# ********** Check convergence criteria **********
#
# Actual simulations so far: 1100
# All cluster are full with 1 times of the bandwidth of 0.0022
# ********** Convergence criteria not reached yet **********
#
#
# ********** Convergence criteria not reached yet, but maximum allowed number of actual simulations reached **********
#
# Simulations evaluated in total 25743:
# Phase 1: Simulations 585, discarding 485, collecting 100 useful results
# Phase 2: Simulations 25158, intelligently discarding 24158, collecting 1000 useful results

# %% [markdown]
# ### Plotting and exporting results

# %%
# Export results
RF.save_prediction_to_file(RESULTS_PATH+'/Phase2')
SDresults.plot_overlapped_SD(fs,PLOT_OVERLAPPED_SD, RESULTS_PATH+'/Phase2')
SDresults.plot_overlapped_SD_stable(fs,PLOT_OVERLAPPED_SD, RESULTS_PATH+'/Phase2')
SDresults.export_results_to_file(RESULTS_PATH+'/Phase2')
kdeSD.plot_kde_freq(RESULTS_PATH+'/Phase2')
# kdeSD.plot_select_modes_clusters(RESULTS_PATH+'/Phase2')
print(f'Found {kdeSD.peaksFFTKDE.shape[0]:d} peaks at {kdeSD.x[kdeSD.peaksFFTKDE]} Hz with prominence of {kdeSD.KDEPROMINENCE:.4f}.\n')
print(f'Found {len(kdeSD.Frequency_dataset):d} poles clusters within {kdeSD.KDEbwFactor:d} times the bandwidth of {kdeSD.bw:.4f} Hz.\n')
# IC
IC_final = kdeSD.information_content(SDresults.selectedpoles_totnum)
# kdeSD.save_plot_IC(count_sim_effective, ICTHRESH, RESULTS_PATH+'/Phase2')
kdeSD.export_results_to_file(RESULTS_PATH+'/Phase2')
modesconv.export_results_to_file(RESULTS_PATH+'/Phase2')

# Mode shape uncertainties analysis, saving and plotting final results
create_results_folder(RESULTS_PATH+'/Phase2/Mode_shapes')
create_results_folder(RESULTS_PATH+'/Phase2/Convergence_Analysis')
create_results_folder(RESULTS_PATH+'/Phase2/Intelligent_sampling_maps')

nodes = pd.read_csv(NODESFILE, header=None, sep="\s+", index_col=False).to_numpy()
connectivity = pd.read_csv(CONNECTIVITYFILE, header=None, sep="\s+", index_col=False).to_numpy()

# modesconv.plot_mode_shapes(N_DIM, nodes, connectivity, MODESCALEFCT, MODESTDFCT, MODESTDFCT_ELLIPSES, MODE2D_DIRECTION, RESULTS_PATH+'/Phase2/Mode_shapes')
modesconv.plot_convergence_curves(CONVMCTHRESH, RESULTS_PATH+'/Phase2/Convergence_Analysis')
SDresults.plot_sampling_maps(RESULTS_PATH+'/Phase2/Intelligent_sampling_maps')
# Out:
# Found 14 peaks at [ 4.22481117  4.52591585  4.87702347  4.95094086  5.74772688  5.99882862
#   6.37711175  8.47940938  9.65991364 10.80454622 12.76770523 14.04495432
#  15.19719604 19.2583046 ] Hz with prominence of 0.0500.
#
# Found 14 poles clusters within 1 times the bandwidth of 0.0022 Hz.

# %% [markdown]
# # Sandbox

# %% [markdown]
# Adjust plot convergence analysis

# %%
def plot_trace(modes_trace_covariance, modes_trace_covariance_rel_diff, freq_mean, CONVMCTHRESH, RESULTS_PATH):
    fig,ax=plt.subplots(figsize=(10,4),facecolor='white')
    fig2,ax2=plt.subplots(figsize=(10,4),facecolor='white')
    for jj in range(modes_trace_covariance.shape[1]):
        ax.plot(np.arange(1,modes_trace_covariance.shape[0]+1), modes_trace_covariance[:,jj],
                 label=f'Mode at {freq_mean[jj]:.2f} Hz', lw=3)
        ax2.plot(np.arange(2,modes_trace_covariance_rel_diff.shape[0]+2), modes_trace_covariance_rel_diff[:,jj],
                 label=f'Mode at {freq_mean[jj]:.2f} Hz', lw=1)
    # ax.xaxis.set_major_locator(mticker.MultipleLocator(1)); ax2.xaxis.set_major_locator(mticker.MultipleLocator(1))
    ax.xaxis.set_major_formatter(FormatStrFormatter('%d')); ax2.xaxis.set_major_formatter(FormatStrFormatter('%d'))

    ax.legend(loc='upper left')
    # plt.legend(loc='upper right',bbox_to_anchor=(0.,0.,1.,0.9),ncol=4,framealpha=0.9)
    ax.set_title('Trace covariance matrix Convergence',fontweight='bold')
    ax.set_xlabel('Actually conducted simulations')
    ax.set_ylim([0,10])
    fig.tight_layout()

    ax2.plot(np.arange(2,modes_trace_covariance_rel_diff.shape[0]+2), CONVMCTHRESH*np.ones(modes_trace_covariance_rel_diff.shape[0]),
             'b--',label='Band $\pm$2%')
    ax2.plot(np.arange(2,modes_trace_covariance_rel_diff.shape[0]+2), -CONVMCTHRESH*np.ones(modes_trace_covariance_rel_diff.shape[0]),'b--')
    ax2.fill_between(np.arange(2,modes_trace_covariance_rel_diff.shape[0]+2), CONVMCTHRESH*np.ones(modes_trace_covariance_rel_diff.shape[0]),
                     -CONVMCTHRESH*np.ones(modes_trace_covariance_rel_diff.shape[0]), color='yellow', alpha=0.5)
    # plt.fill_betweenx([-0.1,0.1], 500, 550, color='#63C7B2',alpha=0.5)
    # plt.text(380, -0.045, 'Convergence ASCBR', fontsize=12,color='#63C7B2',fontweight='bold')
    ax2.set_ylim(-0.1,0.1)
    ax2.legend(loc='upper left')
    ax2.set_title('Relative difference on trace covariance matrix Convergence',fontweight='bold')
    ax2.set_xlabel('Actually conducted simulations')
    fig2.tight_layout()

    fig.savefig(RESULTS_PATH + f'/Trace_covariance_matrix_Convergence_zoom.png', format='png', dpi=300)
    fig2.savefig(RESULTS_PATH + f'/Relative_difference_on_trace_covariance_matrix.png', format='png', dpi=300)

    plt.close('all')

# %%
plot_trace(modesconv.modes_trace_covariance, modesconv.modes_trace_covariance_rel_diff, modesconv.freq_mean[-1], CONVMCTHRESH, RESULTS_PATH+'/Phase2/Convergence_Analysis')

# %% [markdown]
# Change std factor

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.ticker import FormatStrFormatter


def plotModeShape2D(_nodes, _connectivity, ax, color='black',style='solid',annotFlag=False):
    num_frames = _connectivity.shape[0]
    for k in range(num_frames):
        x1 = _nodes[_connectivity[k, 0] - 1, 0]
        y1 = _nodes[_connectivity[k, 0] - 1, 1]
        x2 = _nodes[_connectivity[k, 1] - 1, 0]
        y2 = _nodes[_connectivity[k, 1] - 1, 1]
        xx = [x1, x2]; yy = [y1, y2]
        ax.plot(xx, yy, color=color,linestyle=style,zorder=10)
    for i in range(_nodes.shape[0]):
        xs = _nodes[i, 0]; ys = _nodes[i, 1]
        ax.scatter(xs, ys, color=color, marker='o',zorder=10)
        if annotFlag:
            ax.annotate(f'P{i + 1}', xy=(xs, ys), xytext=(3, 3),
                        textcoords='offset points',zorder=10)

def plot_modes_for_2d(modes_mean, modes_std, freq_mean, _nodes, _connectivity, MODESCALEFCT, MODESTDFCT, MODE2D_DIRECTION, RESULTS_PATH):
    for ii in range(modes_mean.shape[0]):
        fig,ax = plt.subplots(figsize=(6,5),facecolor='white')
        plotModeShape2D(_nodes, _connectivity, ax, color='black', style='dashed', annotFlag=True)
        ax.set_xlabel('x [m]')
        ax.set_ylabel('z [m]')
        nodes_new = np.copy(_nodes)
        if MODE2D_DIRECTION == 'vertical' :
            nodes_new[1:,0] += MODESCALEFCT * modes_mean[ii,:]
            nodes_new_infStd = np.copy(nodes_new)
            nodes_new_supStd = np.copy(nodes_new)
            nodes_new_infStd[1:,0] -= MODESTDFCT * modes_std[ii,:]
            nodes_new_supStd[1:,0] += MODESTDFCT * modes_std[ii,:]
            plotModeShape2D(nodes_new, _connectivity, ax, color='#023e7d', annotFlag=False)
            ax.fill_betweenx(nodes_new[:,1],nodes_new_infStd[:,0],nodes_new_supStd[:,0],
                            color='#9BD0D1',
                            zorder=1,
                            label=f'{MODESTDFCT:.1f} Std. dev.')
        elif MODE2D_DIRECTION == 'horizontal':
            nodes_new[:,1] += MODESCALEFCT * modes_mean[ii,:]
            nodes_new_infStd = np.copy(nodes_new)
            nodes_new_supStd = np.copy(nodes_new)
            nodes_new_infStd[:,1] -= MODESTDFCT * modes_std[ii,:]
            nodes_new_supStd[:,1] += MODESTDFCT * modes_std[ii,:]
            plotModeShape2D(nodes_new, _connectivity, ax, color='#023e7d', annotFlag=False)
            ax.fill_between(nodes_new[:,0],nodes_new_infStd[:,1],nodes_new_supStd[:,1],
                            color='#9BD0D1',
                            zorder=1,
                            label=f'{MODESTDFCT:.1f} Std. dev.')
        else:
            raise ValueError("Error in direction of mode shapes. Accepted arguments: 'horizontal' or 'vertical' ")

        plt.title(f'Mode shape at {freq_mean[ii]:.3f} Hz', fontweight='bold')
        custom_lines = [
                    Line2D([0], [0], color='black',linestyle='dashed', lw=4),
                    Line2D([0], [0], color='#023e7d', lw=4),
                    Patch(facecolor='#9BD0D1', edgecolor=None)
                    ]
        plt.legend(custom_lines,['Undeformed shape','Deformed shape',f'{MODESTDFCT:.1f} Std. dev.'],loc='best')
        plt.ylim(plt.gca().get_ylim()[0],plt.gca().get_ylim()[1]+0.5)
        plt.tight_layout()
        plt.savefig(RESULTS_PATH + f'/Mode_shape_{ii+1}.png', format='png', dpi=300)
        plt.close()

def plot_mode_shapes(N_DIM, nodes, connectivity, MODESCALEFCT, MODESTDFCT, MODESTDFCT_ELLIPSES, MODE2D_DIRECTION, RESULTS_PATH, modesconv):
    if N_DIM == 2:
        plot_modes_for_2d(modesconv.modes_mean[-1], modesconv.modes_std[-1], modesconv.freq_mean[-1], nodes, \
                          connectivity, MODESCALEFCT, MODESTDFCT, MODE2D_DIRECTION, RESULTS_PATH)
        print("2d")
    elif N_DIM == 3: # N_DIM == 3
        plot_modes_for_3d()
    else:
        raise ValueError("Unrecognized Number of dimensions to plot mode shapes")

# %%
# MODESTDFCT=0.1
# N_DIM = 2

# %%
# plot_mode_shapes(N_DIM, nodes, connectivity, MODESCALEFCT, MODESTDFCT, MODESTDFCT_ELLIPSES, MODE2D_DIRECTION, RESULTS_PATH+'/Phase2/Mode_shapes', modesconv)

# %%
# !zip -r /content/RESULTS.zip /content/drive/MyDrive/Roydon_task/code_decision_tree/RESULTS
from google.colab import files
files.download("/content/RESULTS.zip")
